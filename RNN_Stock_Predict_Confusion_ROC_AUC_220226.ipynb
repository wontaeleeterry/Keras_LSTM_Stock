# %%
# Application of Deep Learning to Algorithmic Trading (2017)
# 퀀트 전략을 위한 인공지능 트레이딩 (김태헌, 신준호 지음, 한빛미디어)
# 8.2 RNN을 활용한 주가 방향성 분류 예측 (pp. 285~312)

import pandas as pd
import pandas_datareader as pdr
import numpy as np

np.random.seed(111)


intc_df = pdr.get_data_yahoo('INTC', start = '2000-01-01')     # 인텔 주가

# 시장 상황을 파악할 수 있는 시장 인덱스 데이터
sox_df = pdr.get_data_yahoo('^SOX', start = '2000-01-01')      # 반도체 지수
vix_df = pdr.get_data_yahoo('^VIX', start = '2000-01-01')      # 변동성 지수 : S&P 500 지수 옵션 가격의 향후 30일 동안 변동성
snp500_df = pdr.get_data_yahoo('^GSPC', start = '2000-01-01')  # S&P500 지수

# intc_df.to_csv('intc.csv')
# sox_df.to_csv('sox_df.csv')
# vix_df.to_csv('vix_df.csv')
# snp500_df.to_csv('snp500.csv')

df = pd.read_csv('intc.csv', index_col='Date', parse_dates=True)

# %%
# TA-Lib 활용(맥 M1에서 설치 완료 - 220221)
# brew install ta-lib
# export TA_INCLUDE_PATH="$(brew --prefix ta-lib)/include"
# export TA_LIBRARY_PATH="$(brew --prefix ta-lib)/lib"
# pip install ta-lib
# "python3.8 -m pip install ta-lib" (220221, 이 코드 실행 시 정상 설치 완료)
# 실습 환경 : Macbook air M1, tf24_Py38 (miniconda)

# 기술적 분석을 수행하는 시스템 트레이딩에서 사용하는 라이브러리
# 주요 기능으로 MACD, RSI, 확률, 볼린저 밴드 등과 같은 138개 지표를 사용할 수 있도록
# 내장 함수를 지원한다.
# 윈도우 버전에서 설치 시 비공식적인 윈도우용 바이러니 파일을 이용해서 설치해야 하는 단점이 있다.

import talib

# %%
## 데이터 불러오기 ##
df['next_rtn'] = df['Close'] / df['Open'] - 1  
# 다음날 수익률을 예측하도록 문제를 정의한다.
# 다음날 시가와 종가간의 수정 종가를 하루 미뤄줌으로써 레이블링 데이터를 만든다? / 당일 수익률? (220221)

df['log_return'] = np.log(1 + df['Adj Close'].pct_change())

## 이동 평균(Moving Average) ##

# 이동 평균선(5일, 10일)
df['MA5'] = talib.SMA(df['Close'], timeperiod=5)
df['MA10'] = talib.SMA(df['Close'], timeperiod=10)

# 이동 표준 편차(5일, 10일)
df['RASD5'] = talib.SMA(talib.STDDEV(df['Close'], timeperiod=5, nbdev=1), timeperiod=5)
df['RASD10'] = talib.SMA(talib.STDDEV(df['Close'], timeperiod=5, nbdev=1), timeperiod=10)


## MACD(Moving Average Convergence & Divergence) : 모멘텀 트렌드 지표 ##
macd, macdsignal, macdhidst = talib.MACD(df['Close'], fastperiod=12, slowperiod=26, signalperiod=9)
df['MACD'] = macd

## 모멘텀 지표 ##
# CCI : Commodity Channel Index
df['CCI'] = talib.CCI(df['High'], df['Low'], df['Close'], timeperiod=14)

## 변동성 지표 ##
# ATR : Average True Range
df['ATR'] = talib.ATR(df['High'], df['Low'], df['Close'], timeperiod=14)

## 볼린저 밴드 ##
upper, middle, lower = talib.BBANDS(df['Close'], timeperiod=20, nbdevup=2, nbdevdn=2, matype=0)
df['ub'] = upper
df['middle'] = middle
df['lb'] = lower

## MTM1 MTM3 ##
df['MTM1'] = talib.MOM(df['Close'], timeperiod=1)
df['MTM3'] = talib.MOM(df['Close'], timeperiod=3)

## Rate of Change 지표 ##
df['ROC'] = talib.ROC(df['Close'], timeperiod=60)

## Williams' %R ##
df['WPR'] = talib.WILLR(df['High'], df['Low'], df['Close'], timeperiod=14)

# %%
df.head()
# Out:
#                High       Low       Open     Close      Volume  Adj Close  \
# Date
# 1999-12-31  41.9375  40.96875  41.906250  41.15625  11572000.0  25.017096
# 2000-01-03  43.6875  41.62500  41.632812  43.50000  57710200.0  26.441755
# 2000-01-04  43.9375  41.12500  42.718750  41.46875  51019600.0  25.207056
# 2000-01-05  42.9375  40.25000  41.500000  41.81250  52389000.0  25.416004
# 2000-01-06  41.6875  39.09375  40.875000  39.37500  55171200.0  23.934357
#
#             next_rtn  log_return      MA5  MA10  ...  MACD  CCI  ATR  ub  \
# Date                                             ...
# 1999-12-31 -0.017897         NaN      NaN   NaN  ...   NaN  NaN  NaN NaN
# 2000-01-03  0.044849    0.055385      NaN   NaN  ...   NaN  NaN  NaN NaN
# 2000-01-04 -0.029261   -0.047820      NaN   NaN  ...   NaN  NaN  NaN NaN
# 2000-01-05  0.007530    0.008255      NaN   NaN  ...   NaN  NaN  NaN NaN
# 2000-01-06 -0.036697   -0.060064  41.4625   NaN  ...   NaN  NaN  NaN NaN
#
#             middle  lb     MTM1     MTM3  ROC  WPR
# Date
# 1999-12-31     NaN NaN      NaN      NaN  NaN  NaN
# 2000-01-03     NaN NaN  2.34375      NaN  NaN  NaN
# 2000-01-04     NaN NaN -2.03125      NaN  NaN  NaN
# 2000-01-05     NaN NaN  0.34375  0.65625  NaN  NaN
# 2000-01-06     NaN NaN -2.43750 -4.12500  NaN  NaN
#
# [5 rows x 22 columns]

# %%
df.tail()
# Out:
#                  High        Low       Open      Close      Volume  Adj Close  \
# Date
# 2022-02-15  48.459999  47.189999  47.700001  48.439999  35857500.0  48.439999
# 2022-02-16  48.490002  47.599998  48.060001  48.230000  26022900.0  48.230000
# 2022-02-17  48.259998  47.380001  47.860001  47.570000  32030600.0  47.570000
# 2022-02-18  46.209999  44.509998  46.189999  45.040001  76481700.0  45.040001
# 2022-02-22  45.410000  43.849998  44.689999  44.689999  57079300.0  44.689999
#
#             next_rtn  log_return        MA5    MA10  ...      MACD  \
# Date                                                 ...
# 2022-02-15  0.015514    0.017913  48.484000  48.521  ... -1.060437
# 2022-02-16  0.003537   -0.004345  48.148000  48.393  ... -1.030095
# 2022-02-17 -0.006059   -0.013779  47.890000  48.322  ... -1.047233
# 2022-02-18 -0.024897   -0.054651  47.372000  48.025  ... -1.250549
# 2022-02-22  0.000000   -0.007801  46.793999  47.676  ... -1.423512
#
#                    CCI       ATR         ub   middle         lb      MTM1  \
# Date
# 2022-02-15  -53.798543  1.388346  53.121848  49.5545  45.987151  0.859997
# 2022-02-16  -38.251383  1.352750  52.364068  49.2850  46.205932 -0.209999
# 2022-02-17  -94.228908  1.318982  51.951325  49.0615  46.171675 -0.660000
# 2022-02-18 -288.500152  1.443340  51.764578  48.7115  45.658422 -2.529999
# 2022-02-22 -235.045096  1.451673  51.502651  48.3490  45.195349 -0.350002
#
#                 MTM3        ROC        WPR
# Date
# 2022-02-15 -0.420002  -2.495978 -43.085155
# 2022-02-16  0.599998  -2.605010 -47.411464
# 2022-02-17 -0.010002  -4.535425 -83.916119
# 2022-02-18 -3.399998  -8.268834 -90.292998
# 2022-02-22 -3.540001 -10.188906 -86.274513
#
# [5 rows x 22 columns]

# %%
# 가공된 데이터 프레임(df) 옆에 시장 지수 데이터 추가


# 데이터의 원본을 보존하기 위해 데이터를 복사해두는 것이라면,
# panda.DataFrame.copy()를 사용해야한다 (220221)

snp500_df = snp500_df.loc[:,['Close']].copy()
snp500_df.rename(columns={'Close':'S&P500'}, inplace=True)

sox_df = sox_df.loc[:,['Close']].copy()
sox_df.rename(columns={'Close':'SOX'}, inplace=True)

vix_df = vix_df.loc[:,['Close']].copy()
vix_df.rename(columns={'Close':'VIX'}, inplace=True)

df = df.join(snp500_df, how='left')
df = df.join(sox_df, how='left')
df = df.join(vix_df, how='left')

df.tail()
# Out:
#                  High        Low       Open      Close      Volume  Adj Close  \
# Date
# 2022-02-15  48.459999  47.189999  47.700001  48.439999  35857500.0  48.439999
# 2022-02-16  48.490002  47.599998  48.060001  48.230000  26022900.0  48.230000
# 2022-02-17  48.259998  47.380001  47.860001  47.570000  32030600.0  47.570000
# 2022-02-18  46.209999  44.509998  46.189999  45.040001  76481700.0  45.040001
# 2022-02-22  45.410000  43.849998  44.689999  44.689999  57079300.0  44.689999
#
#             next_rtn  log_return        MA5    MA10  ...         ub   middle  \
# Date                                                 ...
# 2022-02-15  0.015514    0.017913  48.484000  48.521  ...  53.121848  49.5545
# 2022-02-16  0.003537   -0.004345  48.148000  48.393  ...  52.364068  49.2850
# 2022-02-17 -0.006059   -0.013779  47.890000  48.322  ...  51.951325  49.0615
# 2022-02-18 -0.024897   -0.054651  47.372000  48.025  ...  51.764578  48.7115
# 2022-02-22  0.000000   -0.007801  46.793999  47.676  ...  51.502651  48.3490
#
#                    lb      MTM1      MTM3        ROC        WPR       S&P500  \
# Date
# 2022-02-15  45.987151  0.859997 -0.420002  -2.495978 -43.085155  4471.069824
# 2022-02-16  46.205932 -0.209999  0.599998  -2.605010 -47.411464  4475.009766
# 2022-02-17  46.171675 -0.660000 -0.010002  -4.535425 -83.916119  4380.259766
# 2022-02-18  45.658422 -2.529999 -3.399998  -8.268834 -90.292998  4348.870117
# 2022-02-22  45.195349 -0.350002 -3.540001 -10.188906 -86.274513  4304.759766
#
#                     SOX        VIX
# Date
# 2022-02-15  3554.449951  25.700001
# 2022-02-16  3555.689941  24.290001
# 2022-02-17  3422.600098  28.110001
# 2022-02-18  3384.300049  27.750000
# 2022-02-22  3356.070068  28.809999
#
# [5 rows x 25 columns]

# %%
# 주가 변동 관찰 : 상승 구간 / 상승-하락 구간 / 변동 없는 구간 관찰 (220221)

import matplotlib.pyplot as plt
import datetime

plt.figure(figsize = (8, 5))
plt.plot(df['Close'])    # 종가(Close) 데이터 그래프로 확인

x_min = datetime.datetime(2010, 1, 1)
x_max = datetime.datetime(2017, 12, 30)
plt.xlim(x_min, x_max)
plt.ylim(10, 50)

plt.show()

# %%
# 분석을 위한 모든 변수가 포함된 데이터 프레임 완료 (220221)
## 데이터를 : 학습 - 검증 - 테스트 데이터 셋으로 구간(시간)별로 나눈다.

# 특성 목록
FEATURE_LIST_1 = ['Open', 'High', 'Low', 'Adj Close', 'Volume', 'log_return']
FEATURE_LIST_2 = ['RASD5', 'RASD10', 'ub', 'lb', 'CCI', 'ATR', 'MACD', 'MA5', 
                  'MA10', 'MTM1', 'MTM3', 'ROC', 'WPR']
FEATURE_LIST_3 = ['S&P500', 'SOX', 'VIX']
FEATURE_LIST_4 = ['next_rtn']

ALL_FEATURES = FEATURE_LIST_1 + FEATURE_LIST_2 + FEATURE_LIST_3 + FEATURE_LIST_4

# 데이터 셋의 기간 구분
# 2010~2017년 까지 3개의 구간으로 나누어 학습
# 1구간 : 주가가 상승하는 시기 / 2구간 : 하락+상승하는 시기 / 3구간 : 변동이 미미한 시기
PHASE_FLAG = '3'


if PHASE_FLAG == '1':
    train_from = '2010-01-04'
    train_to = '2012-01-01'
    
    val_from = '2012-01-01'
    val_to = '2012-04-01'
    
    test_from = '2012-04-01'
    test_to = '2012-07-01'
    
    
elif PHASE_FLAG == '2':
    train_from = '2010-07-01'
    train_to = '2014-07-01'
    
    val_from = '2014-07-01'
    val_to = '2014-10-01'
    
    test_from = '2014-10-01'
    test_to = '2015-01-01'
    
    
else :
    train_from = '2015-01-01'
    train_to = '2017-01-01'
    
    val_from = '2017-01-01'
    val_to = '2017-04-01'
    
    test_from = '2017-04-01'
    test_to = '2017-07-01'
    
    
# 학습 / 검증 / 테스트

# 데이터의 원본을 보존하기 위해 데이터를 복사해두는 것이라면,
# panda.DataFrame.copy()를 사용해야한다 (220221)

train_df = df.loc[train_from:train_to, ALL_FEATURES].copy()
val_df = df.loc[val_from:val_to, ALL_FEATURES].copy()
test_df = df.loc[test_from:test_to, ALL_FEATURES].copy()

# %%
# 정규화 하기 전, 훈련 셋의 데이터 분석

for x in ALL_FEATURES:
    print("columns : {}".format(x), "Max : {:.3f}".format(train_df[x].max()), 
          "min : {:.3f}".format(train_df[x].min()),
          "mean : {:.3f}".format(train_df[x].mean()), )
# Out:
# columns : Open Max : 38.250 min : 25.200 mean : 32.725
# columns : High Max : 38.360 min : 27.150 mean : 33.035
# columns : Low Max : 37.900 min : 24.870 mean : 32.436
# columns : Adj Close Max : 33.033 min : 21.725 mean : 27.779
# columns : Volume Max : 107402400.000 min : 5893800.000 mean : 26581258.333
# columns : log_return Max : 0.062 min : -0.095 mean : 0.000
# columns : RASD5 Max : 1.083 min : 0.075 mean : 0.365
# columns : RASD10 Max : 0.916 min : 0.097 mean : 0.366
# columns : ub Max : 39.179 min : 29.595 mean : 34.322
# columns : lb Max : 36.737 min : 26.054 mean : 31.193
# columns : CCI Max : 287.226 min : -315.499 mean : 4.797
# columns : ATR Max : 0.986 min : 0.416 mean : 0.661
# columns : MACD Max : 1.271 min : -1.220 mean : -0.004
# columns : MA5 Max : 37.944 min : 26.702 mean : 32.755
# columns : MA10 Max : 37.716 min : 27.437 mean : 32.756
# columns : MTM1 Max : 1.920 min : -2.980 mean : -0.000
# columns : MTM3 Max : 2.550 min : -3.150 mean : -0.001
# columns : ROC Max : 28.179 min : -23.825 mean : 0.874
# columns : WPR Max : -0.000 min : -100.000 mean : -45.287
# columns : S&P500 Max : 2271.720 min : 1829.080 mean : 2077.860
# columns : SOX Max : 939.210 min : 559.180 mean : 702.027
# columns : VIX Max : 40.740 min : 11.270 mean : 16.250
# columns : next_rtn Max : 0.066 min : -0.043 mean : 0.001

# %%
print("PHASE_FLAG: ", PHASE_FLAG)
print("train_df: ",len(train_df))
print("val_df: ",len(val_df))
print("test_df: ",len(test_df))
# Out:
# PHASE_FLAG:  3
# train_df:  504
# val_df:  62
# test_df:  63

# %%
# 1구간 : 주가가 상승하는 시기 / 2구간 : 하락+상승하는 시기 / 3구간 : 변동이 미미한 시기
# 각 기간에 따라 예측 구간에서 그래프가 어떻게 나오는지 확인 필요
# 시계열이 짧을수록 딥러닝 모델을 활용한 전략의 성능이 좋지 못할 확률이 크다.

## 정규화 ##

# 학습을 진행할 때 각각의 특성 데이터가 상이한 범주를 가진다면
# 학습과정이 원활하지 않을 수 있다. ----> 정규화 필요

# 최소-최대 정규화 (min-max normalization)

from sklearn.preprocessing import MinMaxScaler

def min_max_normal(tmp_df):
    eng_list = []
    sample_df = tmp_df.copy()
    
    for x in ALL_FEATURES:
        if x in FEATURE_LIST_4 :    # "next_rtn"컬럼 (당일 수익률?)에 값이 있다면 아래 코드 계속 진행 (220221) ??
            continue
            
        series = sample_df[x].copy()
        values = series.values
        values = values.reshape((len(values), 1))
        
        # 스케일러 생성 및 훈련
        scaler = MinMaxScaler(feature_range=(0, 1))  # 0~1 사이의 값으로 정규화
        scaler = scaler.fit(values)
        
        # 데이터셋 정규화 및 출력
        normalized = scaler.transform(values)
        new_feature = '{}_normal'.format(x)    # 정규화 처리되었다는 뜻으로 새롭게 컬럼 네이밍 처리
        eng_list.append(new_feature)
        sample_df[new_feature] = normalized    # 새롭게 네이밍 처리된 컬럼으로 데이터 프레임 제작
    
    return sample_df, eng_list

# %%
# 학습 / 검증 / 테스트 : 정규화 처리

train_sample_df, eng_list = min_max_normal(train_df)
val_sample_df, eng_list = min_max_normal(val_df)
test_sample_df, eng_list = min_max_normal(test_df)

# %%
print(eng_list)
print(len(eng_list))
# Out:
# ['Open_normal', 'High_normal', 'Low_normal', 'Adj Close_normal', 'Volume_normal', 'log_return_normal', 'RASD5_normal', 'RASD10_normal', 'ub_normal', 'lb_normal', 'CCI_normal', 'ATR_normal', 'MACD_normal', 'MA5_normal', 'MA10_normal', 'MTM1_normal', 'MTM3_normal', 'ROC_normal', 'WPR_normal', 'S&P500_normal', 'SOX_normal', 'VIX_normal']
# 22

# %%
train_sample_df.head()
# Out:
#                  Open       High        Low  Adj Close      Volume  \
# Date
# 2015-01-02  36.669998  37.160000  36.110001  29.850746  23605600.0
# 2015-01-05  36.200001  36.450001  35.939999  29.514143  32785000.0
# 2015-01-06  36.080002  36.230000  35.259998  28.964088  30847600.0
# 2015-01-07  35.639999  36.070000  35.270000  29.571609  27725200.0
# 2015-01-08  36.369999  37.000000  36.259998  30.121660  31765400.0
#
#             log_return     RASD5    RASD10         ub         lb  ...  \
# Date                                                              ...
# 2015-01-02    0.001927  0.360369  0.422398  37.964195  35.625804  ...
# 2015-01-05   -0.011340  0.359143  0.416504  37.902114  35.536885  ...
# 2015-01-06   -0.018813  0.429746  0.417354  37.855069  35.344930  ...
# 2015-01-07    0.020758  0.449678  0.396641  37.788620  35.293380  ...
# 2015-01-08    0.018430  0.450896  0.396890  37.770449  35.291550  ...
#
#             MACD_normal  MA5_normal  MA10_normal  MTM1_normal  MTM3_normal  \
# Date
# 2015-01-02     0.611705    0.900729     0.926549     0.622449     0.408772
# 2015-01-05     0.576726    0.872265     0.916140     0.524490     0.410527
# 2015-01-06     0.526877    0.838463     0.905536     0.471428     0.375438
# 2015-01-07     0.511096    0.825298     0.893959     0.759184     0.492983
# 2015-01-08     0.519944    0.832414     0.886759     0.744898     0.682456
#
#             ROC_normal  WPR_normal  S&P500_normal  SOX_normal  VIX_normal
# Date
# 2015-01-02    0.624169    0.427385       0.517622    0.335631    0.221242
# 2015-01-05    0.552398    0.257261       0.432631    0.301055    0.293519
# 2015-01-06    0.553077    0.008065       0.392034    0.262216    0.334238
# 2015-01-07    0.705804    0.306452       0.444650    0.279162    0.272820
# 2015-01-08    0.777092    0.576612       0.526523    0.330158    0.194774
#
# [5 rows x 45 columns]

# %%
# 정규화 실행 후, 훈련 셋의 데이터 분석

for x in eng_list:
    print("columns : {}".format(x), "Max : {:.3f}".format(train_sample_df[x].max()), 
          "min : {:.3f}".format(train_sample_df[x].min()),
          "mean : {:.3f}".format(train_sample_df[x].mean()), )
# Out:
# columns : Open_normal Max : 1.000 min : 0.000 mean : 0.577
# columns : High_normal Max : 1.000 min : 0.000 mean : 0.525
# columns : Low_normal Max : 1.000 min : 0.000 mean : 0.581
# columns : Adj Close_normal Max : 1.000 min : 0.000 mean : 0.535
# columns : Volume_normal Max : 1.000 min : 0.000 mean : 0.204
# columns : log_return_normal Max : 1.000 min : 0.000 mean : 0.607
# columns : RASD5_normal Max : 1.000 min : 0.000 mean : 0.288
# columns : RASD10_normal Max : 1.000 min : 0.000 mean : 0.328
# columns : ub_normal Max : 1.000 min : 0.000 mean : 0.493
# columns : lb_normal Max : 1.000 min : 0.000 mean : 0.481
# columns : CCI_normal Max : 1.000 min : 0.000 mean : 0.531
# columns : ATR_normal Max : 1.000 min : 0.000 mean : 0.429
# columns : MACD_normal Max : 1.000 min : 0.000 mean : 0.488
# columns : MA5_normal Max : 1.000 min : 0.000 mean : 0.538
# columns : MA10_normal Max : 1.000 min : 0.000 mean : 0.517
# columns : MTM1_normal Max : 1.000 min : 0.000 mean : 0.608
# columns : MTM3_normal Max : 1.000 min : 0.000 mean : 0.552
# columns : ROC_normal Max : 1.000 min : 0.000 mean : 0.475
# columns : WPR_normal Max : 1.000 min : 0.000 mean : 0.547
# columns : S&P500_normal Max : 1.000 min : 0.000 mean : 0.562
# columns : SOX_normal Max : 1.000 min : 0.000 mean : 0.376
# columns : VIX_normal Max : 1.000 min : 0.000 mean : 0.169

# %%
# 학습 데이터와 레이블 데이터 분할
# 목표 --> 다음 영업일 종가 예측
# 특성 데이터와 레이블 데이터를 구분

# LSTM 모델에 넣어줄 변수 데이터를 선택


def create_dateset_binary(data, feature_list, step, n):
    
    train_xdata = np.array(data[feature_list[0:n]])
    print(feature_list[0:n])
    m = np.arange(len(train_xdata) - step)         # 가장 마지막 단계 
    x, y = [], []
    
    for i in m :
        a = train_xdata[i:(i+step)]                 # step 만큼의 과거 기간을 입력으로 전달
        x.append(a)
    
    x_batch = np.reshape(np.array(x), (len(m), step, n))  # 신경망 학습에 사용할 수 있는 형태, 3차원 데이터
                                                          # len(m) : 배치 사이즈(batch_size)
    train_ydata = np.array(data[[feature_list[n]]])       # 레이블링 데이터 -> 다음날 종가를 이용
    
    # n_step 이상부터 답을 사용할 수 있다.      
    for i in m + step :
        next_rtn = train_ydata[i][0]
        if next_rtn > 0 :
            label = 1            # 주가 방향성 : 오른다 1
        else :
            label = 0            # 주가 방향성 : 내린다 0
    
        y.append(label)                      # 순차적으로 레이블 저장
    
    y_batch = np.reshape(np.array(y), (-1, 1))  # 학습을 위한 1차원 벡터 형태로 저장
    
    return x_batch, y_batch     


# 그림을 그려서 다시 이해 필요 (220222)

# %%
# 위에서 정의한 함수를 사용하여
# 훈련 / 검증 / 테스트 데이터에 대하여 레이블렝 데이터 나누기
# 정오표 참고 : https://github.com/quant4junior/algoTrade/commit/d61a1cd1a828cb134150f2f0c2ebd894624f03f7#

eng_list = eng_list + FEATURE_LIST_4  # VIX_normal 전달되지 않는 문제 --> 정오표 확인 후 수정 (220222)
num_step = 5
num_unit = 200
n_feature = len(eng_list)-1

x_train, y_train = create_dateset_binary(train_sample_df[eng_list], eng_list, num_step, n_feature)
x_val, y_val = create_dateset_binary(val_sample_df[eng_list], eng_list, num_step, n_feature)
x_test, y_test = create_dateset_binary(test_sample_df[eng_list], eng_list, num_step, n_feature)
# Out:
# ['Open_normal', 'High_normal', 'Low_normal', 'Adj Close_normal', 'Volume_normal', 'log_return_normal', 'RASD5_normal', 'RASD10_normal', 'ub_normal', 'lb_normal', 'CCI_normal', 'ATR_normal', 'MACD_normal', 'MA5_normal', 'MA10_normal', 'MTM1_normal', 'MTM3_normal', 'ROC_normal', 'WPR_normal', 'S&P500_normal', 'SOX_normal', 'VIX_normal']
# ['Open_normal', 'High_normal', 'Low_normal', 'Adj Close_normal', 'Volume_normal', 'log_return_normal', 'RASD5_normal', 'RASD10_normal', 'ub_normal', 'lb_normal', 'CCI_normal', 'ATR_normal', 'MACD_normal', 'MA5_normal', 'MA10_normal', 'MTM1_normal', 'MTM3_normal', 'ROC_normal', 'WPR_normal', 'S&P500_normal', 'SOX_normal', 'VIX_normal']
# ['Open_normal', 'High_normal', 'Low_normal', 'Adj Close_normal', 'Volume_normal', 'log_return_normal', 'RASD5_normal', 'RASD10_normal', 'ub_normal', 'lb_normal', 'CCI_normal', 'ATR_normal', 'MACD_normal', 'MA5_normal', 'MA10_normal', 'MTM1_normal', 'MTM3_normal', 'ROC_normal', 'WPR_normal', 'S&P500_normal', 'SOX_normal', 'VIX_normal']

# %%
# 책에 나온 결과와 다른 부분 : (497, 5, 22) - (묶음, 타임라인(5일), 변수 갯수)

print(x_train.shape)
print(y_train.shape)
print(x_val.shape)
print(y_val.shape)
print(x_test.shape)
print(y_test.shape)

print(len(eng_list))
# Out:
# (499, 5, 22)
# (499, 1)
# (57, 5, 22)
# (57, 1)
# (58, 5, 22)
# (58, 1)
# 23

# %%
x_train[0, 0,:]

# VIX_normal 값이 전달되지 않음 (220222)
# 야후에서 제공하는 데이터 포맷이 바뀌었나? -> 코드 변경 필요??
# Out:
# array([0.87892706, 0.89295266, 0.86262465, 0.71857504, 0.17448571,
#        0.61891186, 0.2833929 , 0.39743783, 0.87320767, 0.89599294,
#        0.47126977, 0.49100894, 0.61170464, 0.90072938, 0.92654924,
#        0.62244902, 0.4087722 , 0.62416874, 0.42738541, 0.51762152,
#        0.33563134, 0.22124195])

# %%
train_sample_df[eng_list].head()

# 분할 데이터에 정확하게 전달된 것 확인 (220222)
# 정오표 깃허브 확인 수 코드 수정
# Out:
#             Open_normal  High_normal  Low_normal  Adj Close_normal  \
# Date
# 2015-01-02     0.878927     0.892953    0.862625          0.718575
# 2015-01-05     0.842912     0.829616    0.849578          0.688810
# 2015-01-06     0.833717     0.809991    0.797390          0.640169
# 2015-01-07     0.800000     0.795718    0.798158          0.693891
# 2015-01-08     0.855939     0.878680    0.874136          0.742532
#
#             Volume_normal  log_return_normal  RASD5_normal  RASD10_normal  \
# Date
# 2015-01-02       0.174486           0.618912      0.283393       0.397438
# 2015-01-05       0.264915           0.534571      0.282178       0.390239
# 2015-01-06       0.245829           0.487068      0.352179       0.391277
# 2015-01-07       0.215069           0.738619      0.371941       0.365975
# 2015-01-08       0.254871           0.723819      0.373148       0.366279
#
#             ub_normal  lb_normal  ...  MA5_normal  MA10_normal  MTM1_normal  \
# Date                              ...
# 2015-01-02   0.873208   0.895993  ...    0.900729     0.926549     0.622449
# 2015-01-05   0.866731   0.887670  ...    0.872265     0.916140     0.524490
# 2015-01-06   0.861823   0.869702  ...    0.838463     0.905536     0.471428
# 2015-01-07   0.854890   0.864876  ...    0.825298     0.893959     0.759184
# 2015-01-08   0.852994   0.864705  ...    0.832414     0.886759     0.744898
#
#             MTM3_normal  ROC_normal  WPR_normal  S&P500_normal  SOX_normal  \
# Date
# 2015-01-02     0.408772    0.624169    0.427385       0.517622    0.335631
# 2015-01-05     0.410527    0.552398    0.257261       0.432631    0.301055
# 2015-01-06     0.375438    0.553077    0.008065       0.392034    0.262216
# 2015-01-07     0.492983    0.705804    0.306452       0.444650    0.279162
# 2015-01-08     0.682456    0.777092    0.576612       0.526523    0.330158
#
#             VIX_normal  next_rtn
# Date
# 2015-01-02    0.221242 -0.008454
# 2015-01-05    0.293519 -0.006906
# 2015-01-06    0.334238 -0.022173
# 2015-01-07    0.272820  0.010662
# 2015-01-08    0.194774  0.008798
#
# [5 rows x 23 columns]

# %%
# 데이터 수정 : 정오표 참고 (22022)
# 범주형 변수로 변환해야 한다.
# LSTM 모델의 출력부 참고 : output_layer = Dense(2, activation = 'sigmoid')(layer_lstm_5)

from tensorflow.keras.utils import to_categorical

y_train = to_categorical(y_train, 2)
y_val = to_categorical(y_val, 2)
y_test = to_categorical(y_test, 2)

# %%
# print(y_train)

# %%
## LSTM 모델 생성 ##

from tensorflow.keras.models import Model
from tensorflow.keras.models import load_model
from tensorflow.keras.layers import Input, Dense, LSTM
from tensorflow.keras.layers import Activation, BatchNormalization
from tensorflow.keras.layers import Dropout
from tensorflow.keras import backend as K
from tensorflow.keras import regularizers

# %%
# 메모리 해제
K.clear_session()

input_layer = Input(batch_shape = (None, x_train.shape[1], x_train.shape[2]))
# None : 데이터의 갯수를 의미 -> 임의의 스칼라를 의미함, 어떤 숫자가 와도 된다는 의미

layer_lstm_1 = LSTM(num_unit, return_sequences = True, 
                    recurrent_regularizer = regularizers.l2(0.01))(input_layer)
layer_lstm_1 = BatchNormalization()(layer_lstm_1)


layer_lstm_2 = LSTM(num_unit, return_sequences = True, 
                    recurrent_regularizer = regularizers.l2(0.01))(layer_lstm_1)
layer_lstm_2 = Dropout(0.25)(layer_lstm_2)


layer_lstm_3 = LSTM(num_unit, return_sequences = True, 
                    recurrent_regularizer = regularizers.l2(0.01))(layer_lstm_2)
layer_lstm_3 = BatchNormalization()(layer_lstm_3)


layer_lstm_4 = LSTM(num_unit, return_sequences = True, 
                    recurrent_regularizer = regularizers.l2(0.01))(layer_lstm_3)
layer_lstm_4 = Dropout(0.25)(layer_lstm_4)


layer_lstm_5 = LSTM(num_unit, recurrent_regularizer = regularizers.l2(0.01))(layer_lstm_4)
layer_lstm_5 = BatchNormalization()(layer_lstm_5)

output_layer = Dense(2, activation = 'sigmoid')(layer_lstm_5)

model = Model(input_layer, output_layer)
model.compile(loss = 'categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 5, 22)]           0
# _________________________________________________________________
# lstm (LSTM)                  (None, 5, 200)            178400
# _________________________________________________________________
# batch_normalization (BatchNo (None, 5, 200)            800
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 5, 200)            320800
# _________________________________________________________________
# dropout (Dropout)            (None, 5, 200)            0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 5, 200)            320800
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 5, 200)            800
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 5, 200)            320800
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 5, 200)            0
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 200)               320800
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 200)               800
# _________________________________________________________________
# dense (Dense)                (None, 2)                 402
# =================================================================
# Total params: 1,464,402
# Trainable params: 1,463,202
# Non-trainable params: 1,200
# _________________________________________________________________

# %%
# 모델 학습

history = model.fit(x_train, y_train, epochs=200, batch_size=10, verbose=1, validation_data=(x_val, y_val))

# verbose - 옵션에 따라 학습 진행 중에 로그를 어떻게 볼지 설정
# 0: silent / 1: progress / 2: one line per epoch
# Out:
# Epoch 1/200
# 50/50 [==============================] - 1s 16ms/step - loss: 11.3235 - accuracy: 0.5465 - val_loss: 11.0640 - val_accuracy: 0.4912
# Epoch 2/200
# 50/50 [==============================] - 1s 11ms/step - loss: 11.2065 - accuracy: 0.5399 - val_loss: 11.1922 - val_accuracy: 0.4912
# Epoch 3/200
# 50/50 [==============================] - 1s 11ms/step - loss: 11.2530 - accuracy: 0.5095 - val_loss: 11.2874 - val_accuracy: 0.4912
# Epoch 4/200
# 50/50 [==============================] - 1s 10ms/step - loss: 11.2866 - accuracy: 0.5385 - val_loss: 11.3384 - val_accuracy: 0.5088
# Epoch 5/200
# 50/50 [==============================] - 1s 11ms/step - loss: 11.3809 - accuracy: 0.5173 - val_loss: 11.4362 - val_accuracy: 0.5439
# Epoch 6/200
# 50/50 [==============================] - 1s 11ms/step - loss: 11.4682 - accuracy: 0.5375 - val_loss: 11.5474 - val_accuracy: 0.5439
# Epoch 7/200
# 50/50 [==============================] - 1s 11ms/step - loss: 11.5669 - accuracy: 0.5471 - val_loss: 11.6433 - val_accuracy: 0.4386
# Epoch 8/200
# 50/50 [==============================] - 1s 12ms/step - loss: 11.6566 - accuracy: 0.5335 - val_loss: 11.7229 - val_accuracy: 0.5088
# Epoch 9/200
# 50/50 [==============================] - 1s 10ms/step - loss: 11.7729 - accuracy: 0.5173 - val_loss: 11.8110 - val_accuracy: 0.5088
# Epoch 10/200
# 50/50 [==============================] - 1s 11ms/step - loss: 11.8046 - accuracy: 0.5696 - val_loss: 11.9087 - val_accuracy: 0.4912
# Epoch 11/200
# 50/50 [==============================] - 1s 10ms/step - loss: 11.8893 - accuracy: 0.5926 - val_loss: 12.0021 - val_accuracy: 0.4561
# Epoch 12/200
# 50/50 [==============================] - 1s 12ms/step - loss: 11.9765 - accuracy: 0.5569 - val_loss: 12.0702 - val_accuracy: 0.5263
# Epoch 13/200
# 50/50 [==============================] - 0s 10ms/step - loss: 12.0665 - accuracy: 0.5516 - val_loss: 12.1449 - val_accuracy: 0.4386
# Epoch 14/200
# 50/50 [==============================] - 0s 9ms/step - loss: 12.0970 - accuracy: 0.6228 - val_loss: 12.2779 - val_accuracy: 0.4737
# Epoch 15/200
# 50/50 [==============================] - 0s 9ms/step - loss: 12.2463 - accuracy: 0.4797 - val_loss: 12.3413 - val_accuracy: 0.5439
# Epoch 16/200
# 50/50 [==============================] - 0s 9ms/step - loss: 12.2923 - accuracy: 0.5694 - val_loss: 12.5409 - val_accuracy: 0.5088
# Epoch 17/200
# 50/50 [==============================] - 0s 10ms/step - loss: 12.4736 - accuracy: 0.5834 - val_loss: 12.6478 - val_accuracy: 0.4737
# Epoch 18/200
# 50/50 [==============================] - 0s 9ms/step - loss: 12.6787 - accuracy: 0.4997 - val_loss: 13.4586 - val_accuracy: 0.5088
# Epoch 19/200
# 50/50 [==============================] - 0s 9ms/step - loss: 13.5981 - accuracy: 0.5474 - val_loss: 14.0196 - val_accuracy: 0.4912
# Epoch 20/200
# 50/50 [==============================] - 0s 9ms/step - loss: 14.0183 - accuracy: 0.5513 - val_loss: 14.1357 - val_accuracy: 0.5088
# Epoch 21/200
# 50/50 [==============================] - 0s 10ms/step - loss: 14.1625 - accuracy: 0.5494 - val_loss: 14.2474 - val_accuracy: 0.4912
# Epoch 22/200
# 50/50 [==============================] - 0s 9ms/step - loss: 14.2371 - accuracy: 0.5804 - val_loss: 14.4233 - val_accuracy: 0.4912
# Epoch 23/200
# 50/50 [==============================] - 0s 9ms/step - loss: 14.2982 - accuracy: 0.5619 - val_loss: 14.3813 - val_accuracy: 0.4035
# Epoch 24/200
# 50/50 [==============================] - 0s 10ms/step - loss: 14.3305 - accuracy: 0.5993 - val_loss: 14.4453 - val_accuracy: 0.5263
# Epoch 25/200
# 50/50 [==============================] - 0s 9ms/step - loss: 14.4181 - accuracy: 0.5687 - val_loss: 14.4799 - val_accuracy: 0.4035
# Epoch 26/200
# 50/50 [==============================] - 0s 9ms/step - loss: 14.4623 - accuracy: 0.5401 - val_loss: 14.5342 - val_accuracy: 0.5263
# Epoch 27/200
# 50/50 [==============================] - 0s 9ms/step - loss: 14.5118 - accuracy: 0.5711 - val_loss: 14.6341 - val_accuracy: 0.5439
# Epoch 28/200
# 50/50 [==============================] - 0s 9ms/step - loss: 14.5822 - accuracy: 0.5828 - val_loss: 14.6895 - val_accuracy: 0.4912
# Epoch 29/200
# 50/50 [==============================] - 0s 9ms/step - loss: 14.6643 - accuracy: 0.6103 - val_loss: 14.7405 - val_accuracy: 0.5263
# Epoch 30/200
# 50/50 [==============================] - 0s 9ms/step - loss: 14.7497 - accuracy: 0.5713 - val_loss: 14.8657 - val_accuracy: 0.4912
# Epoch 31/200
# 50/50 [==============================] - 0s 9ms/step - loss: 14.8235 - accuracy: 0.5880 - val_loss: 14.9376 - val_accuracy: 0.4035
# Epoch 32/200
# 50/50 [==============================] - 0s 8ms/step - loss: 14.8813 - accuracy: 0.5816 - val_loss: 14.9925 - val_accuracy: 0.5614
# Epoch 33/200
# 50/50 [==============================] - 0s 9ms/step - loss: 14.8901 - accuracy: 0.6002 - val_loss: 15.0236 - val_accuracy: 0.5088
# Epoch 34/200
# 50/50 [==============================] - 0s 9ms/step - loss: 14.9359 - accuracy: 0.5945 - val_loss: 15.0697 - val_accuracy: 0.4386
# Epoch 35/200
# 50/50 [==============================] - 0s 9ms/step - loss: 14.9652 - accuracy: 0.5547 - val_loss: 15.0719 - val_accuracy: 0.5088
# Epoch 36/200
# 50/50 [==============================] - 0s 9ms/step - loss: 15.0039 - accuracy: 0.5765 - val_loss: 15.0662 - val_accuracy: 0.5263
# Epoch 37/200
# 50/50 [==============================] - 0s 8ms/step - loss: 15.0422 - accuracy: 0.6304 - val_loss: 15.1332 - val_accuracy: 0.5088
# Epoch 38/200
# 50/50 [==============================] - 0s 9ms/step - loss: 15.0421 - accuracy: 0.6704 - val_loss: 15.1736 - val_accuracy: 0.4386
# Epoch 39/200
# 50/50 [==============================] - 0s 9ms/step - loss: 15.1211 - accuracy: 0.6053 - val_loss: 15.2287 - val_accuracy: 0.4561
# Epoch 40/200
# 50/50 [==============================] - 0s 9ms/step - loss: 15.1718 - accuracy: 0.5902 - val_loss: 15.2352 - val_accuracy: 0.4912
# Epoch 41/200
# 50/50 [==============================] - 0s 9ms/step - loss: 15.2036 - accuracy: 0.5977 - val_loss: 15.2892 - val_accuracy: 0.4737
# Epoch 42/200
# 50/50 [==============================] - 0s 9ms/step - loss: 15.2299 - accuracy: 0.6259 - val_loss: 15.3622 - val_accuracy: 0.4912
# Epoch 43/200
# 50/50 [==============================] - 0s 9ms/step - loss: 15.3166 - accuracy: 0.5805 - val_loss: 15.4534 - val_accuracy: 0.5965
# Epoch 44/200
# 50/50 [==============================] - 0s 9ms/step - loss: 15.3865 - accuracy: 0.6055 - val_loss: 15.5692 - val_accuracy: 0.4035
# Epoch 45/200
# 50/50 [==============================] - 0s 9ms/step - loss: 15.4605 - accuracy: 0.6440 - val_loss: 15.6367 - val_accuracy: 0.4561
# Epoch 46/200
# 50/50 [==============================] - 0s 9ms/step - loss: 15.5796 - accuracy: 0.5626 - val_loss: 15.6544 - val_accuracy: 0.4561
# Epoch 47/200
# 50/50 [==============================] - 0s 9ms/step - loss: 15.5955 - accuracy: 0.6019 - val_loss: 15.7418 - val_accuracy: 0.5263
# Epoch 48/200
# 50/50 [==============================] - 0s 9ms/step - loss: 15.6875 - accuracy: 0.5990 - val_loss: 15.8750 - val_accuracy: 0.5088
# Epoch 49/200
# 50/50 [==============================] - 0s 9ms/step - loss: 15.7940 - accuracy: 0.6327 - val_loss: 16.0463 - val_accuracy: 0.4737
# Epoch 50/200
# 50/50 [==============================] - 0s 9ms/step - loss: 15.9491 - accuracy: 0.6213 - val_loss: 16.1732 - val_accuracy: 0.4386
# Epoch 51/200
# 50/50 [==============================] - 0s 9ms/step - loss: 16.0637 - accuracy: 0.6163 - val_loss: 16.1984 - val_accuracy: 0.4912
# Epoch 52/200
# 50/50 [==============================] - 0s 9ms/step - loss: 16.1134 - accuracy: 0.6230 - val_loss: 16.2425 - val_accuracy: 0.4737
# Epoch 53/200
# 50/50 [==============================] - 0s 9ms/step - loss: 16.2136 - accuracy: 0.5942 - val_loss: 16.3819 - val_accuracy: 0.4737
# Epoch 54/200
# 50/50 [==============================] - 0s 9ms/step - loss: 16.2972 - accuracy: 0.5869 - val_loss: 16.4205 - val_accuracy: 0.4737
# Epoch 55/200
# 50/50 [==============================] - 0s 9ms/step - loss: 16.3497 - accuracy: 0.6104 - val_loss: 16.5353 - val_accuracy: 0.4737
# Epoch 56/200
# 50/50 [==============================] - 0s 9ms/step - loss: 16.4627 - accuracy: 0.6254 - val_loss: 16.6314 - val_accuracy: 0.5088
# Epoch 57/200
# 50/50 [==============================] - 0s 9ms/step - loss: 16.5773 - accuracy: 0.6447 - val_loss: 16.7915 - val_accuracy: 0.4737
# Epoch 58/200
# 50/50 [==============================] - 0s 9ms/step - loss: 16.6425 - accuracy: 0.6367 - val_loss: 16.8567 - val_accuracy: 0.4561
# Epoch 59/200
# 50/50 [==============================] - 1s 10ms/step - loss: 16.7729 - accuracy: 0.6164 - val_loss: 16.9991 - val_accuracy: 0.4561
# Epoch 60/200
# 50/50 [==============================] - 0s 8ms/step - loss: 16.9384 - accuracy: 0.6122 - val_loss: 17.1714 - val_accuracy: 0.4386
# Epoch 61/200
# 50/50 [==============================] - 0s 8ms/step - loss: 17.0976 - accuracy: 0.5688 - val_loss: 17.2978 - val_accuracy: 0.4737
# Epoch 62/200
# 50/50 [==============================] - 0s 9ms/step - loss: 17.2428 - accuracy: 0.6546 - val_loss: 17.4520 - val_accuracy: 0.4386
# Epoch 63/200
# 50/50 [==============================] - 0s 9ms/step - loss: 17.3892 - accuracy: 0.5730 - val_loss: 17.5246 - val_accuracy: 0.4737
# Epoch 64/200
# 50/50 [==============================] - 0s 9ms/step - loss: 17.4425 - accuracy: 0.6253 - val_loss: 17.7956 - val_accuracy: 0.4912
# Epoch 65/200
# 50/50 [==============================] - 0s 9ms/step - loss: 17.6783 - accuracy: 0.5522 - val_loss: 17.8504 - val_accuracy: 0.4737
# Epoch 66/200
# 50/50 [==============================] - 0s 8ms/step - loss: 17.7865 - accuracy: 0.5945 - val_loss: 17.9095 - val_accuracy: 0.4912
# Epoch 67/200
# 50/50 [==============================] - 0s 8ms/step - loss: 17.8724 - accuracy: 0.5819 - val_loss: 18.1014 - val_accuracy: 0.4561
# Epoch 68/200
# 50/50 [==============================] - 0s 9ms/step - loss: 17.9856 - accuracy: 0.6074 - val_loss: 18.1669 - val_accuracy: 0.5088
# Epoch 69/200
# 50/50 [==============================] - 0s 9ms/step - loss: 18.0866 - accuracy: 0.5943 - val_loss: 18.2312 - val_accuracy: 0.5088
# Epoch 70/200
# 50/50 [==============================] - 0s 9ms/step - loss: 18.1782 - accuracy: 0.6123 - val_loss: 18.4303 - val_accuracy: 0.4737
# Epoch 71/200
# 50/50 [==============================] - 0s 8ms/step - loss: 18.2767 - accuracy: 0.6124 - val_loss: 18.5289 - val_accuracy: 0.4386
# Epoch 72/200
# 50/50 [==============================] - 0s 9ms/step - loss: 18.4518 - accuracy: 0.5834 - val_loss: 18.7291 - val_accuracy: 0.5263
# Epoch 73/200
# 50/50 [==============================] - 0s 9ms/step - loss: 18.6046 - accuracy: 0.6243 - val_loss: 18.8729 - val_accuracy: 0.4912
# Epoch 74/200
# 50/50 [==============================] - 0s 8ms/step - loss: 18.7993 - accuracy: 0.5950 - val_loss: 18.9541 - val_accuracy: 0.5088
# Epoch 75/200
# 50/50 [==============================] - 0s 8ms/step - loss: 18.9305 - accuracy: 0.6163 - val_loss: 19.0893 - val_accuracy: 0.5263
# Epoch 76/200
# 50/50 [==============================] - 0s 9ms/step - loss: 19.0947 - accuracy: 0.5748 - val_loss: 19.4014 - val_accuracy: 0.4561
# Epoch 77/200
# 50/50 [==============================] - 0s 9ms/step - loss: 19.3069 - accuracy: 0.5734 - val_loss: 19.5077 - val_accuracy: 0.4737
# Epoch 78/200
# 50/50 [==============================] - 0s 9ms/step - loss: 19.4479 - accuracy: 0.5977 - val_loss: 19.7256 - val_accuracy: 0.5088
# Epoch 79/200
# 50/50 [==============================] - 0s 9ms/step - loss: 19.5798 - accuracy: 0.5955 - val_loss: 19.8902 - val_accuracy: 0.4211
# Epoch 80/200
# 50/50 [==============================] - 0s 9ms/step - loss: 19.6688 - accuracy: 0.6069 - val_loss: 20.0386 - val_accuracy: 0.4737
# Epoch 81/200
# 50/50 [==============================] - 0s 8ms/step - loss: 19.8184 - accuracy: 0.6209 - val_loss: 20.5519 - val_accuracy: 0.4912
# Epoch 82/200
# 50/50 [==============================] - 0s 8ms/step - loss: 20.0754 - accuracy: 0.6119 - val_loss: 20.3375 - val_accuracy: 0.5263
# Epoch 83/200
# 50/50 [==============================] - 0s 9ms/step - loss: 20.3525 - accuracy: 0.6037 - val_loss: 20.6913 - val_accuracy: 0.5088
# Epoch 84/200
# 50/50 [==============================] - 0s 9ms/step - loss: 20.5941 - accuracy: 0.6655 - val_loss: 20.8854 - val_accuracy: 0.4386
# Epoch 85/200
# 50/50 [==============================] - 0s 9ms/step - loss: 20.8148 - accuracy: 0.5978 - val_loss: 21.1017 - val_accuracy: 0.4737
# Epoch 86/200
# 50/50 [==============================] - 0s 9ms/step - loss: 20.9150 - accuracy: 0.6629 - val_loss: 21.3976 - val_accuracy: 0.4386
# Epoch 87/200
# 50/50 [==============================] - 0s 9ms/step - loss: 21.0589 - accuracy: 0.6186 - val_loss: 21.2275 - val_accuracy: 0.4912
# Epoch 88/200
# 50/50 [==============================] - 0s 9ms/step - loss: 21.1809 - accuracy: 0.5828 - val_loss: 21.4298 - val_accuracy: 0.5088
# Epoch 89/200
# 50/50 [==============================] - 0s 9ms/step - loss: 21.3134 - accuracy: 0.6416 - val_loss: 21.6899 - val_accuracy: 0.4912
# Epoch 90/200
# 50/50 [==============================] - 0s 9ms/step - loss: 21.6239 - accuracy: 0.6204 - val_loss: 22.2694 - val_accuracy: 0.4386
# Epoch 91/200
# 50/50 [==============================] - 0s 9ms/step - loss: 22.2070 - accuracy: 0.5963 - val_loss: 22.5415 - val_accuracy: 0.4737
# Epoch 92/200
# 50/50 [==============================] - 0s 9ms/step - loss: 22.3770 - accuracy: 0.5922 - val_loss: 22.7202 - val_accuracy: 0.5088
# Epoch 93/200
# 50/50 [==============================] - 0s 9ms/step - loss: 22.5660 - accuracy: 0.6607 - val_loss: 22.9031 - val_accuracy: 0.3684
# Epoch 94/200
# 50/50 [==============================] - 0s 8ms/step - loss: 22.8592 - accuracy: 0.5712 - val_loss: 23.0631 - val_accuracy: 0.4912
# Epoch 95/200
# 50/50 [==============================] - 1s 10ms/step - loss: 22.9198 - accuracy: 0.6163 - val_loss: 23.2485 - val_accuracy: 0.5088
# Epoch 96/200
# 50/50 [==============================] - 0s 9ms/step - loss: 23.1106 - accuracy: 0.6204 - val_loss: 23.4315 - val_accuracy: 0.4737
# Epoch 97/200
# 50/50 [==============================] - 0s 9ms/step - loss: 23.2726 - accuracy: 0.5818 - val_loss: 23.8262 - val_accuracy: 0.4737
# Epoch 98/200
# 50/50 [==============================] - 1s 12ms/step - loss: 23.4129 - accuracy: 0.6300 - val_loss: 23.9402 - val_accuracy: 0.5088
# Epoch 99/200
# 50/50 [==============================] - 1s 12ms/step - loss: 23.7215 - accuracy: 0.6203 - val_loss: 24.1979 - val_accuracy: 0.4737
# Epoch 100/200
# 50/50 [==============================] - 1s 10ms/step - loss: 23.9617 - accuracy: 0.6011 - val_loss: 24.6147 - val_accuracy: 0.4737
# Epoch 101/200
# 50/50 [==============================] - 0s 9ms/step - loss: 24.3354 - accuracy: 0.6903 - val_loss: 24.8118 - val_accuracy: 0.5088
# Epoch 102/200
# 50/50 [==============================] - 0s 9ms/step - loss: 24.5504 - accuracy: 0.6314 - val_loss: 25.7281 - val_accuracy: 0.4561
# Epoch 103/200
# 50/50 [==============================] - 0s 9ms/step - loss: 24.9257 - accuracy: 0.6139 - val_loss: 25.3857 - val_accuracy: 0.4737
# Epoch 104/200
# 50/50 [==============================] - 0s 9ms/step - loss: 25.2160 - accuracy: 0.6419 - val_loss: 25.6590 - val_accuracy: 0.4561
# Epoch 105/200
# 50/50 [==============================] - 0s 9ms/step - loss: 25.5810 - accuracy: 0.6056 - val_loss: 26.1395 - val_accuracy: 0.4561
# Epoch 106/200
# 50/50 [==============================] - 0s 9ms/step - loss: 25.7908 - accuracy: 0.6248 - val_loss: 26.1980 - val_accuracy: 0.5789
# Epoch 107/200
# 50/50 [==============================] - 0s 9ms/step - loss: 26.0005 - accuracy: 0.6743 - val_loss: 26.4018 - val_accuracy: 0.5263
# Epoch 108/200
# 50/50 [==============================] - 0s 9ms/step - loss: 26.3337 - accuracy: 0.6396 - val_loss: 26.6368 - val_accuracy: 0.4737
# Epoch 109/200
# 50/50 [==============================] - 0s 9ms/step - loss: 26.5307 - accuracy: 0.6464 - val_loss: 27.2450 - val_accuracy: 0.4737
# Epoch 110/200
# 50/50 [==============================] - 0s 9ms/step - loss: 26.9415 - accuracy: 0.5940 - val_loss: 27.4771 - val_accuracy: 0.4737
# Epoch 111/200
# 50/50 [==============================] - 0s 9ms/step - loss: 27.2892 - accuracy: 0.6395 - val_loss: 28.0346 - val_accuracy: 0.5088
# Epoch 112/200
# 50/50 [==============================] - 0s 9ms/step - loss: 27.6411 - accuracy: 0.6956 - val_loss: 28.1854 - val_accuracy: 0.4386
# Epoch 113/200
# 50/50 [==============================] - 0s 10ms/step - loss: 27.9421 - accuracy: 0.6690 - val_loss: 28.4854 - val_accuracy: 0.4737
# Epoch 114/200
# 50/50 [==============================] - 0s 9ms/step - loss: 28.2566 - accuracy: 0.6271 - val_loss: 28.6637 - val_accuracy: 0.4561
# Epoch 115/200
# 50/50 [==============================] - 0s 9ms/step - loss: 28.3912 - accuracy: 0.6736 - val_loss: 29.3206 - val_accuracy: 0.4561
# Epoch 116/200
# 50/50 [==============================] - 0s 9ms/step - loss: 28.8775 - accuracy: 0.6435 - val_loss: 29.2694 - val_accuracy: 0.4386
# Epoch 117/200
# 50/50 [==============================] - 0s 9ms/step - loss: 29.0436 - accuracy: 0.6433 - val_loss: 29.4722 - val_accuracy: 0.4561
# Epoch 118/200
# 50/50 [==============================] - 0s 9ms/step - loss: 29.2262 - accuracy: 0.6558 - val_loss: 29.6774 - val_accuracy: 0.4912
# Epoch 119/200
# 50/50 [==============================] - 0s 9ms/step - loss: 29.4645 - accuracy: 0.6325 - val_loss: 30.2601 - val_accuracy: 0.3860
# Epoch 120/200
# 50/50 [==============================] - 0s 9ms/step - loss: 29.9851 - accuracy: 0.6645 - val_loss: 30.6628 - val_accuracy: 0.4912
# Epoch 121/200
# 50/50 [==============================] - 0s 9ms/step - loss: 30.4356 - accuracy: 0.6500 - val_loss: 30.9154 - val_accuracy: 0.4912
# Epoch 122/200
# 50/50 [==============================] - 0s 9ms/step - loss: 30.7304 - accuracy: 0.6688 - val_loss: 31.3529 - val_accuracy: 0.5088
# Epoch 123/200
# 50/50 [==============================] - 0s 9ms/step - loss: 31.0197 - accuracy: 0.6421 - val_loss: 31.8125 - val_accuracy: 0.4035
# Epoch 124/200
# 50/50 [==============================] - 0s 9ms/step - loss: 31.4090 - accuracy: 0.6951 - val_loss: 32.3592 - val_accuracy: 0.4737
# Epoch 125/200
# 50/50 [==============================] - 0s 9ms/step - loss: 31.8526 - accuracy: 0.6902 - val_loss: 32.8280 - val_accuracy: 0.4912
# Epoch 126/200
# 50/50 [==============================] - 0s 9ms/step - loss: 32.4905 - accuracy: 0.6532 - val_loss: 33.2573 - val_accuracy: 0.4386
# Epoch 127/200
# 50/50 [==============================] - 0s 9ms/step - loss: 32.9451 - accuracy: 0.6828 - val_loss: 34.2419 - val_accuracy: 0.4561
# Epoch 128/200
# 50/50 [==============================] - 0s 9ms/step - loss: 33.4533 - accuracy: 0.6960 - val_loss: 34.4621 - val_accuracy: 0.4211
# Epoch 129/200
# 50/50 [==============================] - 0s 9ms/step - loss: 34.0612 - accuracy: 0.6957 - val_loss: 34.8274 - val_accuracy: 0.4561
# Epoch 130/200
# 50/50 [==============================] - 0s 9ms/step - loss: 34.3775 - accuracy: 0.7060 - val_loss: 35.3988 - val_accuracy: 0.4561
# Epoch 131/200
# 50/50 [==============================] - 0s 9ms/step - loss: 34.7092 - accuracy: 0.7274 - val_loss: 36.0313 - val_accuracy: 0.4035
# Epoch 132/200
# 50/50 [==============================] - 0s 9ms/step - loss: 35.5529 - accuracy: 0.6625 - val_loss: 36.3026 - val_accuracy: 0.4737
# Epoch 133/200
# 50/50 [==============================] - 0s 9ms/step - loss: 35.7740 - accuracy: 0.7071 - val_loss: 36.8456 - val_accuracy: 0.5088
# Epoch 134/200
# 50/50 [==============================] - 0s 9ms/step - loss: 36.1350 - accuracy: 0.7136 - val_loss: 37.0419 - val_accuracy: 0.5088
# Epoch 135/200
# 50/50 [==============================] - 0s 9ms/step - loss: 36.6651 - accuracy: 0.7349 - val_loss: 37.8891 - val_accuracy: 0.4912
# Epoch 136/200
# 50/50 [==============================] - 0s 9ms/step - loss: 37.2368 - accuracy: 0.7275 - val_loss: 38.1996 - val_accuracy: 0.5263
# Epoch 137/200
# 50/50 [==============================] - 0s 9ms/step - loss: 37.7519 - accuracy: 0.7405 - val_loss: 38.7996 - val_accuracy: 0.4737
# Epoch 138/200
# 50/50 [==============================] - 0s 9ms/step - loss: 38.3177 - accuracy: 0.7718 - val_loss: 39.5797 - val_accuracy: 0.5088
# Epoch 139/200
# 50/50 [==============================] - 0s 9ms/step - loss: 39.3646 - accuracy: 0.7113 - val_loss: 42.2442 - val_accuracy: 0.4912
# Epoch 140/200
# 50/50 [==============================] - 0s 9ms/step - loss: 39.7117 - accuracy: 0.7579 - val_loss: 41.1510 - val_accuracy: 0.4737
# Epoch 141/200
# 50/50 [==============================] - 0s 9ms/step - loss: 40.5533 - accuracy: 0.7065 - val_loss: 41.8905 - val_accuracy: 0.4035
# Epoch 142/200
# 50/50 [==============================] - 0s 9ms/step - loss: 41.0487 - accuracy: 0.7365 - val_loss: 42.2110 - val_accuracy: 0.4035
# Epoch 143/200
# 50/50 [==============================] - 0s 9ms/step - loss: 41.8516 - accuracy: 0.7781 - val_loss: 43.3357 - val_accuracy: 0.4912
# Epoch 144/200
# 50/50 [==============================] - 0s 9ms/step - loss: 42.5540 - accuracy: 0.8123 - val_loss: 43.6955 - val_accuracy: 0.4035
# Epoch 145/200
# 50/50 [==============================] - 0s 9ms/step - loss: 43.2727 - accuracy: 0.7619 - val_loss: 44.3130 - val_accuracy: 0.3860
# Epoch 146/200
# 50/50 [==============================] - 0s 9ms/step - loss: 43.6907 - accuracy: 0.8235 - val_loss: 45.0721 - val_accuracy: 0.3860
# Epoch 147/200
# 50/50 [==============================] - 0s 9ms/step - loss: 44.2953 - accuracy: 0.8158 - val_loss: 46.0495 - val_accuracy: 0.4737
# Epoch 148/200
# 50/50 [==============================] - 0s 9ms/step - loss: 44.9937 - accuracy: 0.8062 - val_loss: 46.8111 - val_accuracy: 0.4386
# Epoch 149/200
# 50/50 [==============================] - 0s 9ms/step - loss: 45.7921 - accuracy: 0.8134 - val_loss: 47.2428 - val_accuracy: 0.4035
# Epoch 150/200
# 50/50 [==============================] - 0s 9ms/step - loss: 46.7514 - accuracy: 0.7830 - val_loss: 48.1130 - val_accuracy: 0.4035
# Epoch 151/200
# 50/50 [==============================] - 0s 9ms/step - loss: 47.2799 - accuracy: 0.8542 - val_loss: 48.8261 - val_accuracy: 0.3860
# Epoch 152/200
# 50/50 [==============================] - 0s 9ms/step - loss: 47.8125 - accuracy: 0.8476 - val_loss: 49.2081 - val_accuracy: 0.4211
# Epoch 153/200
# 50/50 [==============================] - 0s 9ms/step - loss: 48.5299 - accuracy: 0.8834 - val_loss: 50.2388 - val_accuracy: 0.4211
# Epoch 154/200
# 50/50 [==============================] - 0s 9ms/step - loss: 49.1984 - accuracy: 0.8785 - val_loss: 50.9718 - val_accuracy: 0.3684
# Epoch 155/200
# 50/50 [==============================] - 0s 9ms/step - loss: 49.7854 - accuracy: 0.8588 - val_loss: 51.5385 - val_accuracy: 0.4561
# Epoch 156/200
# 50/50 [==============================] - 0s 9ms/step - loss: 50.6598 - accuracy: 0.9062 - val_loss: 52.1475 - val_accuracy: 0.4561
# Epoch 157/200
# 50/50 [==============================] - 0s 9ms/step - loss: 51.3584 - accuracy: 0.8554 - val_loss: 53.4712 - val_accuracy: 0.4737
# Epoch 158/200
# 50/50 [==============================] - 0s 9ms/step - loss: 51.9650 - accuracy: 0.8776 - val_loss: 54.2142 - val_accuracy: 0.4386
# Epoch 159/200
# 50/50 [==============================] - 0s 9ms/step - loss: 52.7714 - accuracy: 0.8911 - val_loss: 54.5752 - val_accuracy: 0.4912
# Epoch 160/200
# 50/50 [==============================] - 0s 9ms/step - loss: 53.7774 - accuracy: 0.8788 - val_loss: 56.8578 - val_accuracy: 0.4561
# Epoch 161/200
# 50/50 [==============================] - 0s 9ms/step - loss: 55.7378 - accuracy: 0.8811 - val_loss: 58.0184 - val_accuracy: 0.4211
# Epoch 162/200
# 50/50 [==============================] - 0s 9ms/step - loss: 56.6426 - accuracy: 0.9227 - val_loss: 59.1460 - val_accuracy: 0.4912
# Epoch 163/200
# 50/50 [==============================] - 0s 9ms/step - loss: 57.8815 - accuracy: 0.8778 - val_loss: 60.4100 - val_accuracy: 0.4211
# Epoch 164/200
# 50/50 [==============================] - 0s 9ms/step - loss: 59.0106 - accuracy: 0.8864 - val_loss: 61.1601 - val_accuracy: 0.4737
# Epoch 165/200
# 50/50 [==============================] - 0s 9ms/step - loss: 59.6938 - accuracy: 0.8755 - val_loss: 61.9439 - val_accuracy: 0.5088
# Epoch 166/200
# 50/50 [==============================] - 0s 9ms/step - loss: 60.1100 - accuracy: 0.8872 - val_loss: 62.8238 - val_accuracy: 0.4211
# Epoch 167/200
# 50/50 [==============================] - 0s 9ms/step - loss: 60.5742 - accuracy: 0.9051 - val_loss: 62.8809 - val_accuracy: 0.3509
# Epoch 168/200
# 50/50 [==============================] - 0s 9ms/step - loss: 60.9295 - accuracy: 0.9173 - val_loss: 62.8904 - val_accuracy: 0.3860
# Epoch 169/200
# 50/50 [==============================] - 0s 9ms/step - loss: 61.4270 - accuracy: 0.9138 - val_loss: 63.8325 - val_accuracy: 0.3509
# Epoch 170/200
# 50/50 [==============================] - 0s 9ms/step - loss: 61.6690 - accuracy: 0.9119 - val_loss: 63.9974 - val_accuracy: 0.3860
# Epoch 171/200
# 50/50 [==============================] - 0s 9ms/step - loss: 62.1496 - accuracy: 0.8856 - val_loss: 63.9891 - val_accuracy: 0.3684
# Epoch 172/200
# 50/50 [==============================] - 0s 9ms/step - loss: 62.6263 - accuracy: 0.9319 - val_loss: 64.8467 - val_accuracy: 0.4035
# Epoch 173/200
# 50/50 [==============================] - 0s 9ms/step - loss: 62.8874 - accuracy: 0.9402 - val_loss: 65.1305 - val_accuracy: 0.4211
# Epoch 174/200
# 50/50 [==============================] - 0s 9ms/step - loss: 63.3704 - accuracy: 0.8733 - val_loss: 65.6321 - val_accuracy: 0.4035
# Epoch 175/200
# 50/50 [==============================] - 0s 9ms/step - loss: 63.9244 - accuracy: 0.8965 - val_loss: 65.8460 - val_accuracy: 0.4386
# Epoch 176/200
# 50/50 [==============================] - 0s 9ms/step - loss: 64.3779 - accuracy: 0.9339 - val_loss: 66.7668 - val_accuracy: 0.4035
# Epoch 177/200
# 50/50 [==============================] - 0s 9ms/step - loss: 64.6471 - accuracy: 0.9560 - val_loss: 68.0059 - val_accuracy: 0.4561
# Epoch 178/200
# 50/50 [==============================] - 0s 9ms/step - loss: 64.9614 - accuracy: 0.9578 - val_loss: 67.4424 - val_accuracy: 0.4035
# Epoch 179/200
# 50/50 [==============================] - 0s 9ms/step - loss: 65.7000 - accuracy: 0.9088 - val_loss: 67.7134 - val_accuracy: 0.4386
# Epoch 180/200
# 50/50 [==============================] - 0s 9ms/step - loss: 66.1775 - accuracy: 0.9492 - val_loss: 68.7046 - val_accuracy: 0.3333
# Epoch 181/200
# 50/50 [==============================] - 0s 9ms/step - loss: 66.5046 - accuracy: 0.9446 - val_loss: 68.5897 - val_accuracy: 0.4211
# Epoch 182/200
# 50/50 [==============================] - 0s 9ms/step - loss: 66.9373 - accuracy: 0.9546 - val_loss: 69.2943 - val_accuracy: 0.3684
# Epoch 183/200
# 50/50 [==============================] - 0s 9ms/step - loss: 67.4700 - accuracy: 0.9097 - val_loss: 69.6352 - val_accuracy: 0.3684
# Epoch 184/200
# 50/50 [==============================] - 0s 9ms/step - loss: 67.8811 - accuracy: 0.9510 - val_loss: 70.1590 - val_accuracy: 0.4737
# Epoch 185/200
# 50/50 [==============================] - 0s 9ms/step - loss: 68.1127 - accuracy: 0.9475 - val_loss: 70.7709 - val_accuracy: 0.4211
# Epoch 186/200
# 50/50 [==============================] - 0s 9ms/step - loss: 68.3841 - accuracy: 0.9672 - val_loss: 71.2298 - val_accuracy: 0.4211
# Epoch 187/200
# 50/50 [==============================] - 0s 9ms/step - loss: 68.6567 - accuracy: 0.9713 - val_loss: 71.3512 - val_accuracy: 0.3684
# Epoch 188/200
# 50/50 [==============================] - 0s 9ms/step - loss: 68.8797 - accuracy: 0.9713 - val_loss: 71.7150 - val_accuracy: 0.4211
# Epoch 189/200
# 50/50 [==============================] - 0s 9ms/step - loss: 69.2321 - accuracy: 0.9598 - val_loss: 71.7917 - val_accuracy: 0.4386
# Epoch 190/200
# 50/50 [==============================] - 0s 9ms/step - loss: 69.7535 - accuracy: 0.9315 - val_loss: 72.2628 - val_accuracy: 0.4386
# Epoch 191/200
# 50/50 [==============================] - 0s 9ms/step - loss: 70.2911 - accuracy: 0.9467 - val_loss: 73.2210 - val_accuracy: 0.3333
# Epoch 192/200
# 50/50 [==============================] - 0s 9ms/step - loss: 70.5358 - accuracy: 0.9748 - val_loss: 73.3505 - val_accuracy: 0.3860
# Epoch 193/200
# 50/50 [==============================] - 0s 9ms/step - loss: 70.9953 - accuracy: 0.9678 - val_loss: 73.3805 - val_accuracy: 0.3684
# Epoch 194/200
# 50/50 [==============================] - 0s 9ms/step - loss: 71.3299 - accuracy: 0.9511 - val_loss: 73.9255 - val_accuracy: 0.3333
# Epoch 195/200
# 50/50 [==============================] - 0s 9ms/step - loss: 71.6732 - accuracy: 0.9622 - val_loss: 74.2849 - val_accuracy: 0.4035
# Epoch 196/200
# 50/50 [==============================] - 0s 9ms/step - loss: 72.0242 - accuracy: 0.9479 - val_loss: 74.4232 - val_accuracy: 0.3509
# Epoch 197/200
# 50/50 [==============================] - 0s 9ms/step - loss: 72.3050 - accuracy: 0.9790 - val_loss: 75.4132 - val_accuracy: 0.4211
# Epoch 198/200
# 50/50 [==============================] - 0s 9ms/step - loss: 72.5546 - accuracy: 0.9774 - val_loss: 75.8370 - val_accuracy: 0.3860
# Epoch 199/200
# 50/50 [==============================] - 0s 9ms/step - loss: 72.7815 - accuracy: 0.9484 - val_loss: 75.3296 - val_accuracy: 0.4386
# Epoch 200/200
# 50/50 [==============================] - 0s 9ms/step - loss: 73.0514 - accuracy: 0.9666 - val_loss: 75.7869 - val_accuracy: 0.4035

# %%
predict = model.predict(x_test)
y_pred = np.argmax(predict, axis=1)
y_test = np.argmax(y_test, axis=1)

# %%
test_sample_df.head()
# Out:
#                  Open       High        Low  Adj Close      Volume  \
# Date
# 2017-04-03  36.189999  36.740002  36.119999  31.814127  32013600.0
# 2017-04-04  36.119999  36.380001  35.990002  31.919704  18918000.0
# 2017-04-05  36.430000  36.759998  36.169998  31.866922  22455500.0
# 2017-04-06  36.130001  36.279999  36.029999  31.699755  20198200.0
# 2017-04-07  36.070000  36.320000  35.990002  31.699755  15689500.0
#
#             log_return     RASD5    RASD10         ub         lb  ...  \
# Date                                                              ...
# 2017-04-03    0.002492  0.197595  0.167640  36.151634  34.829365  ...
# 2017-04-04    0.003313  0.221336  0.180194  36.249550  34.779450  ...
# 2017-04-05   -0.001655  0.224736  0.184453  36.340753  34.748247  ...
# 2017-04-06   -0.005260  0.202725  0.180402  36.370806  34.739194  ...
# 2017-04-07    0.000000  0.177264  0.176360  36.388838  34.733162  ...
#
#             MACD_normal  MA5_normal  MA10_normal  MTM1_normal  MTM3_normal  \
# Date
# 2017-04-03     0.618837    0.658940     0.500000     0.706186     0.874372
# 2017-04-04     0.676361    0.703973     0.548896     0.721649     0.844220
# 2017-04-05     0.715936    0.747020     0.582413     0.628867     0.653267
# 2017-04-06     0.729567    0.765563     0.612381     0.561854     0.512562
# 2017-04-07     0.739421    0.762914     0.646687     0.659794     0.452261
#
#             ROC_normal  WPR_normal  S&P500_normal  SOX_normal  VIX_normal
# Date
# 2017-04-03    0.624991    0.741099       0.240062    0.256901    0.423510
# 2017-04-04    0.622719    0.767917       0.250662    0.227053    0.328502
# 2017-04-05    0.576750    0.725474       0.192756    0.188061    0.505636
# 2017-04-06    0.547370    0.617785       0.229219    0.194569    0.425121
# 2017-04-07    0.450095    0.617785       0.213558    0.220713    0.502415
#
# [5 rows x 45 columns]

# %%
YY_key = test_sample_df['Open'].iloc[5:].keys()  # 맨 앞의 5개 값은 제외 (학습용 데이터)하고 키 값(날짜) 추출
YY_key = np.array(YY_key)

# %%
Y_value_add = pd.DataFrame({
    'Y_test' : y_test,
    'Y_pred' : y_pred,
    'date'   : YY_key
})

Y_value_add.set_index('date', inplace=True)  # 특정 칼럼 'date'를 index로 변경
Y_value_add.head()
# Out:
#             Y_test  Y_pred
# date
# 2017-04-10       0       1
# 2017-04-11       0       1
# 2017-04-12       0       1
# 2017-04-13       0       0
# 2017-04-17       1       0

# %%
plt.figure(figsize=(10, 5))
plt.plot(Y_value_add['Y_test'], '-bo')
plt.plot(Y_value_add['Y_pred'], '-ro')
plt.legend(['Test_set', 'Pred_set'])

# x_min = datetime(2021, 12, 1)
# x_max = datetime(2022, 2, 25)
# plt.xlim(x_min, x_max)
plt.ylim(-0.5, 1.5)

print("정답(Test_set)과 예측 결과(Pred_set)")
plt.show()
# Out:
# 정답(Test_set)과 예측 결과(Pred_set)

# %%
Y_value_add['check'] = (Y_value_add['Y_test'] == Y_value_add['Y_pred'])
True_counts, False_counts = Y_value_add['check'].value_counts()
# print(True_counts)
print(True_counts)
# Out:
# 31

# %%
Y_value_add['check'].value_counts()
# Out:
# True     31
# False    27
# Name: check, dtype: int64

# %%
# Test set을 이용한 정답율(Accuracy) 계산 결과 (220222)

print("Accuracy with Test set : {:.2f}".format(True_counts/len(Y_value_add)*100))
# Out:
# Accuracy with Test set : 53.45

# %%
from sklearn.metrics import classification_report

report = classification_report(Y_value_add['Y_test'], Y_value_add['Y_pred'])

print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.57      0.55      0.56        31
#            1       0.50      0.52      0.51        27
#
#     accuracy                           0.53        58
#    macro avg       0.53      0.53      0.53        58
# weighted avg       0.54      0.53      0.53        58

# %%
from sklearn.metrics import confusion_matrix
import math

cm = confusion_matrix(Y_value_add['Y_test'], Y_value_add['Y_pred'])

tn = cm[0][0]
fn = cm[1][0]
tp = cm[1][1]
fp = cm[0][1]

if tp == 0:
    tp = 1
if tn == 0:
    tn = 1
if fp == 0:
    fp = 1
if fn == 0:
    fn = 1

TPR = float(tp)/(float(tp)+float(fn))
FPR = float(fp)/(float(fp)+float(tn))
accuracy = round((float(tp) + float(tn))/(float(tp) +
                                          float(fp) + float(fn) + float(tn)), 3)
specitivity = round(float(tn)/(float(tn) + float(fp)), 3)
sensitivity = round(float(tp)/(float(tp) + float(fn)), 3)

mcc = round((float(tp)*float(tn) - float(fp)*float(fn))/math.sqrt(
    (float(tp)+float(fp))
    * (float(tp)+float(fn))
    * (float(tn)+float(fp))
    * (float(tn)+float(fn))), 3)

print("TN : ", tn)
print("FN : ", fn)
print("TP : ", tp)
print("FP : ", fp)
print("TPR : ", TPR)
print("FPR : ", FPR)
print("accuracy :", accuracy)
print("specitivity :", specitivity)
print("sensitivity :", sensitivity)
print("mcc :", mcc)
# Out:
# TN :  17
# FN :  13
# TP :  14
# FP :  14
# TPR :  0.5185185185185185
# FPR :  0.45161290322580644
# accuracy : 0.534
# specitivity : 0.548
# sensitivity : 0.519
# mcc : 0.067

# %%
# ROC 곡선 시각화

import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from sklearn.metrics import roc_curve, roc_auc_score

# ROC 그래프 작성 함수
def roc_curve_plot(y_test, y_pred):

    # FPR = FP/(FP+TN)
    # TPR = Recall = TP/(TP + FN)
    
    fprs, tprs, thresholds = roc_curve(y_test, y_pred)
    roc_score= roc_auc_score(y_test, y_pred)

    # print(fprs, tprs)
    # fprs = [0, FPR, 1]          # roc_curve 함수의 반환 값 확인(220226)
    # tprs = [0, sensitivity, 1]
    
    # ROC 그래프 작성
    plt.plot(fprs, tprs, label='ROC')
    # 대각선 직선
    plt.plot([0,1],[0,1], 'k--', label='Random')
    
    start, end = plt.xlim()
    plt.xticks(np.round(np.arange(start, end, 0.1), 2))
    
    plt.xlim(0, 1); plt.ylim(0, 1)
    plt.xlabel('FPR'); plt.ylabel('TPR(Recall) = Sensitivity')
    
    plt.text(0.8, 0.1,'AUC : {:.2f}'.format(roc_score))
    plt.legend()

# 함수 호출 및 ROC 그래프 작성   
roc_curve_plot(Y_value_add['Y_test'], Y_value_add['Y_pred'])
