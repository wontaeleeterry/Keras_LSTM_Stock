# %%
#참고 자료 - https://eeqmeung.tistory.com/2

import pandas as pd
import numpy as np
np.random.seed(111)

import pandas_datareader.data as web
import datetime

start = datetime.datetime(2015, 12, 30)
end = datetime.datetime(2022, 2, 18)

# 야후 API에서 코스피 지수를 pandas 데이터프레임으로 가져오기
# code_name = '^KS11'
code_name = '008770.KS'   # 호텔신라 - 계절/시즌의 성격을 나타낼 수 있지 않을까? (220219)

data = web.DataReader(code_name, "yahoo", start, end)
data.tail()
# Out:
#                High      Low     Open    Close    Volume  Adj Close
# Date
# 2022-02-14  79600.0  77300.0  77400.0  78800.0  381069.0    78800.0
# 2022-02-15  79400.0  77100.0  78700.0  78300.0  312626.0    78300.0
# 2022-02-16  80900.0  79000.0  79500.0  80600.0  558973.0    80600.0
# 2022-02-17  82000.0  78500.0  80500.0  80400.0  804841.0    80400.0
# 2022-02-18  81000.0  79400.0  79400.0  80400.0  295751.0    80400.0

# %%
# 데이터의 갯수가 5로 나누어 떨어져야 한다. (220219)
# 1주일치 (5일) 데이터를 예측하기 위해서.

# 5로 나누어 떨어지지 않는 경우, 시작 날짜를 조정한다.
print(len(data))
# Out:
# 1505

# %%
import matplotlib.pyplot as plt

plt.figure(figsize = (8, 4))
plt.plot(data['Close'])    # 종가(Close) 데이터 그래프로 확인
plt.show()

# %%
data.head()
# Out:
#                High      Low     Open    Close    Volume     Adj Close
# Date
# 2015-12-30  79600.0  77000.0  79600.0  77300.0  530967.0  75324.093750
# 2016-01-04  79300.0  77400.0  77800.0  78100.0  287659.0  76103.640625
# 2016-01-05  78900.0  77400.0  78300.0  78500.0  236187.0  76493.421875
# 2016-01-06  79100.0  76500.0  78900.0  77300.0  370562.0  75324.093750
# 2016-01-07  78300.0  73200.0  77300.0  73500.0  856384.0  71621.226562

# %%
from sklearn.preprocessing import MinMaxScaler
# 데이터 정규화 : 모든 종가 데이터를 0-1사의 값으로 비율로 저장

scalar = MinMaxScaler(feature_range=(0, 1))

data_val = data.filter(['Close']).values 
scaled_data = scalar.fit_transform(data_val)

print(scaled_data)
print(len(scaled_data))
# Out:
# [[0.3867713 ]
#  [0.39573991]
#  [0.40022422]
#  ...
#  [0.42376682]
#  [0.42152466]
#  [0.42152466]]
# 1505

# %%
# train data length
import math
training_data_len = math.ceil(len(scaled_data)*0.9)

print(training_data_len)
print(1505*0.9)                 # 결과 확인 : 데이터의 90%

# 중요 : trainig_data_len이 5로 나누어 떨어지지 않으면 학습이 진행되지 않는다.
# (220219)
# Out:
# 1355
# 1354.5

# %%
# set train data
train_data = scaled_data[0:training_data_len]
print("train data :", train_data)
# Out:
# train data : [[0.3867713 ]
#  [0.39573991]
#  [0.40022422]
#  ...
#  [0.60986547]
#  [0.57286996]
#  [0.56053812]]

# %%
# Append Past_SET to x_train

x_train = []
y_train = []

print(type(x_train))
# Out:
# <class 'list'>

# %%
# 훈련 데이터는 전체 중 0.8의 비중으로 한다.
# 아래 for루프는 LSTM에서 요구하는대로 formatting

# PAST_SET은 예측 날짜로부터 기억할 전날의 크기
# 예를들어, 30은 예측일로부터 30일 전까지의 데이터까지 모두 예측하는데 고려할 날
# --> LSTM의 '기억'이 30일

# PAST_SET = 300  # 계절성을 고려하여 약 1년 분량을 기억한다면? (220219)
PAST_SET = 10

# %%
# for i in range(PAST_SET, len(train_data)):
for i in range(PAST_SET, len(train_data), 5):    # 1주일(5일치 예측)
    x_train.append(train_data[i-PAST_SET:i, 0])
    y_train.append(train_data[i:i+5, 0])


print(type(x_train))

x_train, y_train = np.array(x_train), np.array(y_train)  

print(type(x_train))
print(np.shape(x_train))
print(np.shape(y_train))
# Out:
# <class 'list'>
# <class 'numpy.ndarray'>
# (269, 10)
# (269, 5)

# %%
print(x_train)
print(np.shape(x_train))
print(len(x_train))
# Out:
# [[0.3867713  0.39573991 0.40022422 ... 0.3206278  0.31053812 0.28587444]
#  [0.32286996 0.30605381 0.3206278  ... 0.23766816 0.25       0.23318386]
#  [0.26793722 0.24887892 0.23766816 ... 0.2735426  0.2970852  0.31950673]
#  ...
#  [0.60426009 0.61098655 0.6132287  ... 0.62668161 0.61883408 0.63452915]
#  [0.62668161 0.62780269 0.62668161 ... 0.61210762 0.5896861  0.5941704 ]
#  [0.62107623 0.59080717 0.61210762 ... 0.61098655 0.60762332 0.59529148]]
# (269, 10)
# 269

# %%
print(y_train)
print(len(y_train))
# Out:
# [[0.26793722 0.24887892 0.23766816 0.25       0.23318386]
#  [0.24887892 0.28811659 0.2735426  0.2970852  0.31950673]
#  [0.25       0.26793722 0.26681614 0.29147982 0.3441704 ]
#  ...
#  [0.62107623 0.59080717 0.61210762 0.5896861  0.5941704 ]
#  [0.62331839 0.6132287  0.61098655 0.60762332 0.59529148]
#  [0.59641256 0.59304933 0.60986547 0.57286996 0.56053812]]
# 269

# %%
# LSTM needs to get 3rd shape

x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
print("x_train shape : ", np.shape(x_train))

# 훈련 데이터 셋의 차원 크기 : 2152개의 데이터가 각각 30일 전까지 포함, 뒤 1은 LSTM에서 요구하는 형태이다.
# Out:
# x_train shape :  (269, 10, 1)

# %%
x_train
# Out:
# array([[[0.3867713 ],
#         [0.39573991],
#         [0.40022422],
#         ...,
#         [0.3206278 ],
#         [0.31053812],
#         [0.28587444]],
#
#        [[0.32286996],
#         [0.30605381],
#         [0.3206278 ],
#         ...,
#         [0.23766816],
#         [0.25      ],
#         [0.23318386]],
#
#        [[0.26793722],
#         [0.24887892],
#         [0.23766816],
#         ...,
#         [0.2735426 ],
#         [0.2970852 ],
#         [0.31950673]],
#
#        ...,
#
#        [[0.60426009],
#         [0.61098655],
#         [0.6132287 ],
#         ...,
#         [0.62668161],
#         [0.61883408],
#         [0.63452915]],
#
#        [[0.62668161],
#         [0.62780269],
#         [0.62668161],
#         ...,
#         [0.61210762],
#         [0.5896861 ],
#         [0.5941704 ]],
#
#        [[0.62107623],
#         [0.59080717],
#         [0.61210762],
#         ...,
#         [0.61098655],
#         [0.60762332],
#         [0.59529148]]])

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout

model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(x_train.shape[1], 1)))
model.add(LSTM(50, return_sequences=False))
model.add(Dense(20, activation='relu'))
model.add(Dropout(0.1)) 
model.add(Dense(10, activation='relu'))
# 가중치에 음수가 있으므로 활성화 함수 종류는 큰 차이 없다
model.add(Dropout(0.1))
model.add(Dense(5, activation='sigmoid'))    
# 최종 5개의 다음 값을 예측한다.

# model.compile(optimizer='adam', loss='mean_squared_error')
model.compile(optimizer='adam', loss='mae')



model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 10, 50)            10400
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 50)                20200
# _________________________________________________________________
# dense (Dense)                (None, 20)                1020
# _________________________________________________________________
# dropout (Dropout)            (None, 20)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                210
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 10)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 5)                 55
# =================================================================
# Total params: 31,885
# Trainable params: 31,885
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train
model.fit(x_train, y_train, batch_size=5, epochs=200)
# 배치 사이즈 및 에포크 변경하면서 학습 결과 모니터링(210224)
# Out:
# Epoch 1/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.1722
# Epoch 2/200
# 54/54 [==============================] - 0s 983us/step - loss: 0.1213
# Epoch 3/200
# 54/54 [==============================] - 0s 996us/step - loss: 0.1055
# Epoch 4/200
# 54/54 [==============================] - 0s 987us/step - loss: 0.0955
# Epoch 5/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0867
# Epoch 6/200
# 54/54 [==============================] - 0s 982us/step - loss: 0.0890
# Epoch 7/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0902
# Epoch 8/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.1047
# Epoch 9/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0862
# Epoch 10/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0888
# Epoch 11/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0880
# Epoch 12/200
# 54/54 [==============================] - 0s 960us/step - loss: 0.0839
# Epoch 13/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0774
# Epoch 14/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0805
# Epoch 15/200
# 54/54 [==============================] - 0s 962us/step - loss: 0.0837
# Epoch 16/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0903
# Epoch 17/200
# 54/54 [==============================] - 0s 999us/step - loss: 0.0922
# Epoch 18/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0924
# Epoch 19/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0757
# Epoch 20/200
# 54/54 [==============================] - 0s 983us/step - loss: 0.0875
# Epoch 21/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0643
# Epoch 22/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0722
# Epoch 23/200
# 54/54 [==============================] - 0s 986us/step - loss: 0.0787
# Epoch 24/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0806
# Epoch 25/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0673
# Epoch 26/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0713
# Epoch 27/200
# 54/54 [==============================] - 0s 998us/step - loss: 0.0715
# Epoch 28/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0655
# Epoch 29/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0795
# Epoch 30/200
# 54/54 [==============================] - 0s 996us/step - loss: 0.0766
# Epoch 31/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0715
# Epoch 32/200
# 54/54 [==============================] - 0s 972us/step - loss: 0.0660
# Epoch 33/200
# 54/54 [==============================] - 0s 991us/step - loss: 0.0679
# Epoch 34/200
# 54/54 [==============================] - 0s 996us/step - loss: 0.0687
# Epoch 35/200
# 54/54 [==============================] - 0s 996us/step - loss: 0.0602
# Epoch 36/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0774
# Epoch 37/200
# 54/54 [==============================] - 0s 986us/step - loss: 0.0683
# Epoch 38/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0622
# Epoch 39/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0656
# Epoch 40/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0610
# Epoch 41/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0703
# Epoch 42/200
# 54/54 [==============================] - 0s 940us/step - loss: 0.0630
# Epoch 43/200
# 54/54 [==============================] - 0s 980us/step - loss: 0.0633
# Epoch 44/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0651
# Epoch 45/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0546
# Epoch 46/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0586
# Epoch 47/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0567
# Epoch 48/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0617
# Epoch 49/200
# 54/54 [==============================] - 0s 987us/step - loss: 0.0557
# Epoch 50/200
# 54/54 [==============================] - 0s 969us/step - loss: 0.0523
# Epoch 51/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0559
# Epoch 52/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0556
# Epoch 53/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0526
# Epoch 54/200
# 54/54 [==============================] - 0s 965us/step - loss: 0.0602
# Epoch 55/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0580
# Epoch 56/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0525
# Epoch 57/200
# 54/54 [==============================] - 0s 976us/step - loss: 0.0486
# Epoch 58/200
# 54/54 [==============================] - 0s 993us/step - loss: 0.0557
# Epoch 59/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0618
# Epoch 60/200
# 54/54 [==============================] - 0s 970us/step - loss: 0.0661
# Epoch 61/200
# 54/54 [==============================] - 0s 978us/step - loss: 0.0562
# Epoch 62/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0536
# Epoch 63/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0523
# Epoch 64/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0554
# Epoch 65/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0541
# Epoch 66/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0594
# Epoch 67/200
# 54/54 [==============================] - 0s 990us/step - loss: 0.0520
# Epoch 68/200
# 54/54 [==============================] - 0s 942us/step - loss: 0.0511
# Epoch 69/200
# 54/54 [==============================] - 0s 974us/step - loss: 0.0479
# Epoch 70/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0507
# Epoch 71/200
# 54/54 [==============================] - 0s 987us/step - loss: 0.0463
# Epoch 72/200
# 54/54 [==============================] - 0s 927us/step - loss: 0.0475
# Epoch 73/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0595
# Epoch 74/200
# 54/54 [==============================] - 0s 993us/step - loss: 0.0547
# Epoch 75/200
# 54/54 [==============================] - 0s 966us/step - loss: 0.0580
# Epoch 76/200
# 54/54 [==============================] - 0s 979us/step - loss: 0.0467
# Epoch 77/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0509
# Epoch 78/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0576
# Epoch 79/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0566
# Epoch 80/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0481
# Epoch 81/200
# 54/54 [==============================] - 0s 989us/step - loss: 0.0596
# Epoch 82/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0445
# Epoch 83/200
# 54/54 [==============================] - 0s 958us/step - loss: 0.0447
# Epoch 84/200
# 54/54 [==============================] - 0s 997us/step - loss: 0.0466
# Epoch 85/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0494
# Epoch 86/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0455
# Epoch 87/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0475
# Epoch 88/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0450
# Epoch 89/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0506
# Epoch 90/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0467
# Epoch 91/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0468
# Epoch 92/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0499
# Epoch 93/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0483
# Epoch 94/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0467
# Epoch 95/200
# 54/54 [==============================] - 0s 991us/step - loss: 0.0476
# Epoch 96/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0417
# Epoch 97/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0434
# Epoch 98/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0426
# Epoch 99/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0492
# Epoch 100/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0518
# Epoch 101/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0455
# Epoch 102/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0481
# Epoch 103/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0523
# Epoch 104/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0445
# Epoch 105/200
# 54/54 [==============================] - 0s 996us/step - loss: 0.0484
# Epoch 106/200
# 54/54 [==============================] - 0s 969us/step - loss: 0.0447
# Epoch 107/200
# 54/54 [==============================] - 0s 983us/step - loss: 0.0411
# Epoch 108/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0472
# Epoch 109/200
# 54/54 [==============================] - 0s 978us/step - loss: 0.0444
# Epoch 110/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0498
# Epoch 111/200
# 54/54 [==============================] - 0s 928us/step - loss: 0.0437
# Epoch 112/200
# 54/54 [==============================] - 0s 984us/step - loss: 0.0415
# Epoch 113/200
# 54/54 [==============================] - 0s 978us/step - loss: 0.0545
# Epoch 114/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0434
# Epoch 115/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0360
# Epoch 116/200
# 54/54 [==============================] - 0s 982us/step - loss: 0.0467
# Epoch 117/200
# 54/54 [==============================] - 0s 934us/step - loss: 0.0442
# Epoch 118/200
# 54/54 [==============================] - 0s 972us/step - loss: 0.0453
# Epoch 119/200
# 54/54 [==============================] - 0s 980us/step - loss: 0.0501
# Epoch 120/200
# 54/54 [==============================] - 0s 918us/step - loss: 0.0421
# Epoch 121/200
# 54/54 [==============================] - 0s 971us/step - loss: 0.0467
# Epoch 122/200
# 54/54 [==============================] - 0s 977us/step - loss: 0.0447
# Epoch 123/200
# 54/54 [==============================] - 0s 912us/step - loss: 0.0480
# Epoch 124/200
# 54/54 [==============================] - 0s 964us/step - loss: 0.0520
# Epoch 125/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0459
# Epoch 126/200
# 54/54 [==============================] - 0s 914us/step - loss: 0.0425
# Epoch 127/200
# 54/54 [==============================] - 0s 921us/step - loss: 0.0503
# Epoch 128/200
# 54/54 [==============================] - 0s 965us/step - loss: 0.0494
# Epoch 129/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0503
# Epoch 130/200
# 54/54 [==============================] - 0s 967us/step - loss: 0.0446
# Epoch 131/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0466
# Epoch 132/200
# 54/54 [==============================] - 0s 952us/step - loss: 0.0425
# Epoch 133/200
# 54/54 [==============================] - 0s 967us/step - loss: 0.0455
# Epoch 134/200
# 54/54 [==============================] - 0s 998us/step - loss: 0.0478
# Epoch 135/200
# 54/54 [==============================] - 0s 998us/step - loss: 0.0454
# Epoch 136/200
# 54/54 [==============================] - 0s 978us/step - loss: 0.0471
# Epoch 137/200
# 54/54 [==============================] - 0s 991us/step - loss: 0.0443
# Epoch 138/200
# 54/54 [==============================] - 0s 952us/step - loss: 0.0445
# Epoch 139/200
# 54/54 [==============================] - 0s 989us/step - loss: 0.0435
# Epoch 140/200
# 54/54 [==============================] - 0s 968us/step - loss: 0.0431
# Epoch 141/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0433
# Epoch 142/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0472
# Epoch 143/200
# 54/54 [==============================] - 0s 978us/step - loss: 0.0419
# Epoch 144/200
# 54/54 [==============================] - 0s 1000us/step - loss: 0.0432
# Epoch 145/200
# 54/54 [==============================] - 0s 941us/step - loss: 0.0417
# Epoch 146/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0498
# Epoch 147/200
# 54/54 [==============================] - 0s 967us/step - loss: 0.0437
# Epoch 148/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0438
# Epoch 149/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0460
# Epoch 150/200
# 54/54 [==============================] - 0s 969us/step - loss: 0.0400
# Epoch 151/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0451
# Epoch 152/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0469
# Epoch 153/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0435
# Epoch 154/200
# 54/54 [==============================] - 0s 961us/step - loss: 0.0482
# Epoch 155/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0416
# Epoch 156/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0474
# Epoch 157/200
# 54/54 [==============================] - 0s 955us/step - loss: 0.0448
# Epoch 158/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0396
# Epoch 159/200
# 54/54 [==============================] - 0s 915us/step - loss: 0.0406
# Epoch 160/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0478
# Epoch 161/200
# 54/54 [==============================] - 0s 922us/step - loss: 0.0448
# Epoch 162/200
# 54/54 [==============================] - 0s 920us/step - loss: 0.0416
# Epoch 163/200
# 54/54 [==============================] - 0s 914us/step - loss: 0.0440
# Epoch 164/200
# 54/54 [==============================] - 0s 994us/step - loss: 0.0432
# Epoch 165/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0412
# Epoch 166/200
# 54/54 [==============================] - 0s 958us/step - loss: 0.0491
# Epoch 167/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0465
# Epoch 168/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0382
# Epoch 169/200
# 54/54 [==============================] - 0s 937us/step - loss: 0.0457
# Epoch 170/200
# 54/54 [==============================] - 0s 992us/step - loss: 0.0432
# Epoch 171/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0408
# Epoch 172/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0413
# Epoch 173/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0456
# Epoch 174/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0416
# Epoch 175/200
# 54/54 [==============================] - 0s 956us/step - loss: 0.0473
# Epoch 176/200
# 54/54 [==============================] - 0s 955us/step - loss: 0.0393
# Epoch 177/200
# 54/54 [==============================] - 0s 973us/step - loss: 0.0440
# Epoch 178/200
# 54/54 [==============================] - 0s 957us/step - loss: 0.0471
# Epoch 179/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0420
# Epoch 180/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0472
# Epoch 181/200
# 54/54 [==============================] - 0s 992us/step - loss: 0.0397
# Epoch 182/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0454
# Epoch 183/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0385
# Epoch 184/200
# 54/54 [==============================] - 0s 985us/step - loss: 0.0490
# Epoch 185/200
# 54/54 [==============================] - 0s 930us/step - loss: 0.0469
# Epoch 186/200
# 54/54 [==============================] - 0s 984us/step - loss: 0.0475
# Epoch 187/200
# 54/54 [==============================] - 0s 990us/step - loss: 0.0443
# Epoch 188/200
# 54/54 [==============================] - 0s 977us/step - loss: 0.0521
# Epoch 189/200
# 54/54 [==============================] - 0s 930us/step - loss: 0.0448
# Epoch 190/200
# 54/54 [==============================] - 0s 901us/step - loss: 0.0429
# Epoch 191/200
# 54/54 [==============================] - 0s 897us/step - loss: 0.0406
# Epoch 192/200
# 54/54 [==============================] - 0s 926us/step - loss: 0.0430
# Epoch 193/200
# 54/54 [==============================] - 0s 979us/step - loss: 0.0451
# Epoch 194/200
# 54/54 [==============================] - 0s 964us/step - loss: 0.0507
# Epoch 195/200
# 54/54 [==============================] - 0s 964us/step - loss: 0.0439
# Epoch 196/200
# 54/54 [==============================] - 0s 934us/step - loss: 0.0435
# Epoch 197/200
# 54/54 [==============================] - 0s 953us/step - loss: 0.0470
# Epoch 198/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0494
# Epoch 199/200
# 54/54 [==============================] - 0s 977us/step - loss: 0.0458
# Epoch 200/200
# 54/54 [==============================] - 0s 1ms/step - loss: 0.0505

# %%
test_data = scaled_data[(training_data_len - PAST_SET):, :]

x_test = []
y_test = scaled_data[training_data_len:, :]

print(y_test)
print(test_data)
print(len(test_data))
print(len(y_test))
# Out:
# [[0.55941704]
#  [0.5661435 ]
#  [0.58856502]
#  [0.56950673]
#  [0.57847534]
#  [0.58520179]
#  [0.56726457]
#  [0.56053812]
#  [0.55044843]
#  [0.59641256]
#  [0.57735426]
#  [0.56502242]
#  [0.5706278 ]
#  [0.56950673]
#  [0.57847534]
#  [0.56838565]
#  [0.55717489]
#  [0.55829596]
#  [0.57511211]
#  [0.57286996]
#  [0.57847534]
#  [0.56278027]
#  [0.55381166]
#  [0.55156951]
#  [0.55381166]
#  [0.52914798]
#  [0.49439462]
#  [0.51233184]
#  [0.46860987]
#  [0.46524664]
#  [0.47085202]
#  [0.51345291]
#  [0.50896861]
#  [0.52017937]
#  [0.5190583 ]
#  [0.5190583 ]
#  [0.52690583]
#  [0.51681614]
#  [0.51681614]
#  [0.52017937]
#  [0.52130045]
#  [0.52802691]
#  [0.52130045]
#  [0.50224215]
#  [0.51008969]
#  [0.4955157 ]
#  [0.53363229]
#  [0.52690583]
#  [0.51457399]
#  [0.5190583 ]
#  [0.51233184]
#  [0.51681614]
#  [0.51345291]
#  [0.50336323]
#  [0.48991031]
#  [0.49103139]
#  [0.46973094]
#  [0.51121076]
#  [0.52017937]
#  [0.54035874]
#  [0.53699552]
#  [0.52578475]
#  [0.55493274]
#  [0.55717489]
#  [0.56053812]
#  [0.5470852 ]
#  [0.54035874]
#  [0.52914798]
#  [0.52690583]
#  [0.52242152]
#  [0.5470852 ]
#  [0.54372197]
#  [0.5190583 ]
#  [0.50336323]
#  [0.5       ]
#  [0.42376682]
#  [0.42600897]
#  [0.42713004]
#  [0.42713004]
#  [0.41928251]
#  [0.44618834]
#  [0.44730942]
#  [0.42825112]
#  [0.4293722 ]
#  [0.43161435]
#  [0.43721973]
#  [0.43049327]
#  [0.42152466]
#  [0.41255605]
#  [0.4058296 ]
#  [0.40358744]
#  [0.40358744]
#  [0.40134529]
#  [0.39349776]
#  [0.35986547]
#  [0.32959641]
#  [0.31165919]
#  [0.32735426]
#  [0.3441704 ]
#  [0.37107623]
#  [0.37219731]
#  [0.39125561]
#  [0.38340807]
#  [0.39573991]
#  [0.38565022]
#  [0.38452915]
#  [0.37892377]
#  [0.37556054]
#  [0.37331839]
#  [0.38116592]
#  [0.3632287 ]
#  [0.36883408]
#  [0.39125561]
#  [0.39013453]
#  [0.39349776]
#  [0.39349776]
#  [0.39686099]
#  [0.39798206]
#  [0.39461883]
#  [0.39125561]
#  [0.382287  ]
#  [0.382287  ]
#  [0.3867713 ]
#  [0.35426009]
#  [0.35650224]
#  [0.37219731]
#  [0.40022422]
#  [0.38789238]
#  [0.36210762]
#  [0.35313901]
#  [0.34865471]
#  [0.35538117]
#  [0.36098655]
#  [0.3441704 ]
#  [0.31950673]
#  [0.31950673]
#  [0.30493274]
#  [0.32735426]
#  [0.32847534]
#  [0.37892377]
#  [0.37780269]
#  [0.37780269]
#  [0.37780269]
#  [0.41479821]
#  [0.40358744]
#  [0.40358744]
#  [0.39798206]
#  [0.42376682]
#  [0.42152466]
#  [0.42152466]]
# [[0.62331839]
#  [0.6132287 ]
#  [0.61098655]
#  [0.60762332]
#  [0.59529148]
#  [0.59641256]
#  [0.59304933]
#  [0.60986547]
#  [0.57286996]
#  [0.56053812]
#  [0.55941704]
#  [0.5661435 ]
#  [0.58856502]
#  [0.56950673]
#  [0.57847534]
#  [0.58520179]
#  [0.56726457]
#  [0.56053812]
#  [0.55044843]
#  [0.59641256]
#  [0.57735426]
#  [0.56502242]
#  [0.5706278 ]
#  [0.56950673]
#  [0.57847534]
#  [0.56838565]
#  [0.55717489]
#  [0.55829596]
#  [0.57511211]
#  [0.57286996]
#  [0.57847534]
#  [0.56278027]
#  [0.55381166]
#  [0.55156951]
#  [0.55381166]
#  [0.52914798]
#  [0.49439462]
#  [0.51233184]
#  [0.46860987]
#  [0.46524664]
#  [0.47085202]
#  [0.51345291]
#  [0.50896861]
#  [0.52017937]
#  [0.5190583 ]
#  [0.5190583 ]
#  [0.52690583]
#  [0.51681614]
#  [0.51681614]
#  [0.52017937]
#  [0.52130045]
#  [0.52802691]
#  [0.52130045]
#  [0.50224215]
#  [0.51008969]
#  [0.4955157 ]
#  [0.53363229]
#  [0.52690583]
#  [0.51457399]
#  [0.5190583 ]
#  [0.51233184]
#  [0.51681614]
#  [0.51345291]
#  [0.50336323]
#  [0.48991031]
#  [0.49103139]
#  [0.46973094]
#  [0.51121076]
#  [0.52017937]
#  [0.54035874]
#  [0.53699552]
#  [0.52578475]
#  [0.55493274]
#  [0.55717489]
#  [0.56053812]
#  [0.5470852 ]
#  [0.54035874]
#  [0.52914798]
#  [0.52690583]
#  [0.52242152]
#  [0.5470852 ]
#  [0.54372197]
#  [0.5190583 ]
#  [0.50336323]
#  [0.5       ]
#  [0.42376682]
#  [0.42600897]
#  [0.42713004]
#  [0.42713004]
#  [0.41928251]
#  [0.44618834]
#  [0.44730942]
#  [0.42825112]
#  [0.4293722 ]
#  [0.43161435]
#  [0.43721973]
#  [0.43049327]
#  [0.42152466]
#  [0.41255605]
#  [0.4058296 ]
#  [0.40358744]
#  [0.40358744]
#  [0.40134529]
#  [0.39349776]
#  [0.35986547]
#  [0.32959641]
#  [0.31165919]
#  [0.32735426]
#  [0.3441704 ]
#  [0.37107623]
#  [0.37219731]
#  [0.39125561]
#  [0.38340807]
#  [0.39573991]
#  [0.38565022]
#  [0.38452915]
#  [0.37892377]
#  [0.37556054]
#  [0.37331839]
#  [0.38116592]
#  [0.3632287 ]
#  [0.36883408]
#  [0.39125561]
#  [0.39013453]
#  [0.39349776]
#  [0.39349776]
#  [0.39686099]
#  [0.39798206]
#  [0.39461883]
#  [0.39125561]
#  [0.382287  ]
#  [0.382287  ]
#  [0.3867713 ]
#  [0.35426009]
#  [0.35650224]
#  [0.37219731]
#  [0.40022422]
#  [0.38789238]
#  [0.36210762]
#  [0.35313901]
#  [0.34865471]
#  [0.35538117]
#  [0.36098655]
#  [0.3441704 ]
#  [0.31950673]
#  [0.31950673]
#  [0.30493274]
#  [0.32735426]
#  [0.32847534]
#  [0.37892377]
#  [0.37780269]
#  [0.37780269]
#  [0.37780269]
#  [0.41479821]
#  [0.40358744]
#  [0.40358744]
#  [0.39798206]
#  [0.42376682]
#  [0.42152466]
#  [0.42152466]]
# 160
# 150

# %%
# for i in range(PAST_SET, len(test_data)):
for i in range(PAST_SET, len(test_data), 5):
    x_test.append(test_data[i - PAST_SET:i, 0])

# %%
x_test = np.array(x_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

predictions = model.predict(x_test)

# %%
# un scaling
predictions = scalar.inverse_transform(predictions)

# %%
print(predictions.shape)
# Out:
# (30, 5)

# %%
predictions
# Out:
# array([[92918.61 , 92155.086, 92307.32 , 91539.15 , 92068.13 ],
#        [94077.45 , 93235.5  , 93380.195, 92511.83 , 93091.38 ],
#        [94602.44 , 93725.48 , 93866.71 , 92953.36 , 93555.59 ],
#        [94263.48 , 93409.08 , 93552.555, 92668.2  , 93255.82 ],
#        [94192.02 , 93342.4  , 93486.34 , 92608.125, 93192.64 ],
#        [92474.73 , 91741.63 , 91896.72 , 91167.24 , 91676.664],
#        [83369.27 , 83501.4  , 83597.42 , 83660.875, 83672.33 ],
#        [89108.76 , 88620.73 , 88765.09 , 88353.93 , 88712.64 ],
#        [89165.35 , 88687.37 , 88819.53 , 88407.16 , 88763.26 ],
#        [87060.06 , 86792.805, 86891.59 , 86657.06 , 86928.555],
#        [88681.01 , 88250.39 , 88380.96 , 88008.336, 88338.42 ],
#        [85187.2  , 85107.336, 85185.375, 85108.664, 85291.72 ],
#        [90376.77 , 89789.94 , 89958.164, 89413.45 , 89829.28 ],
#        [92879.414, 92118.57 , 92271.06 , 91506.305, 92033.56 ],
#        [89752.84 , 89229.45 , 89365.11 , 88898.1  , 89281.08 ],
#        [86251.85 , 86071.805, 86149.54 , 85986.83 , 86225.59 ],
#        [81182.72 , 81348.7  , 81638.98 , 81725.35 , 81419.41 ],
#        [82341.42 , 82417.21 , 82676.77 , 82713.17 , 82539.234],
#        [80421.06 , 80588.83 , 80957.39 , 81038.61 , 80619.65 ],
#        [77686.18 , 78030.72 , 78512.414, 78684.44 , 77953.87 ],
#        [75793.85 , 76273.53 , 76804.72 , 77052.96 , 76113.05 ],
#        [78515.71 , 78809.86 , 79255.375, 79399.96 , 78758.88 ],
#        [77816.72 , 78156.26 , 78627.016, 78797.766, 78078.336],
#        [78689.35 , 78968.77 , 79409.77 , 79546.99 , 78924.195],
#        [79003.516, 79259.125, 79691.734, 79816.766, 79229.28 ],
#        [76471.85 , 76899.96 , 77420.76 , 77636.766, 76773.54 ],
#        [76531.18 , 76955.1  , 77475.14 , 77687.89 , 76830.92 ],
#        [74180.57 , 74755.12 , 75356.26 , 75646.65 , 74544.88 ],
#        [75668.55 , 76157.266, 76691.04 , 76943.48 , 75989.14 ],
#        [79768.1  , 79997.52 , 80377.766, 80487.77 , 79999.44 ]],
#       dtype=float32)

# %%
predictions.shape = predictions.shape[0]*predictions.shape[1]

# %%
predictions
# Out:
# array([92918.61 , 92155.086, 92307.32 , 91539.15 , 92068.13 , 94077.45 ,
#        93235.5  , 93380.195, 92511.83 , 93091.38 , 94602.44 , 93725.48 ,
#        93866.71 , 92953.36 , 93555.59 , 94263.48 , 93409.08 , 93552.555,
#        92668.2  , 93255.82 , 94192.02 , 93342.4  , 93486.34 , 92608.125,
#        93192.64 , 92474.73 , 91741.63 , 91896.72 , 91167.24 , 91676.664,
#        83369.27 , 83501.4  , 83597.42 , 83660.875, 83672.33 , 89108.76 ,
#        88620.73 , 88765.09 , 88353.93 , 88712.64 , 89165.35 , 88687.37 ,
#        88819.53 , 88407.16 , 88763.26 , 87060.06 , 86792.805, 86891.59 ,
#        86657.06 , 86928.555, 88681.01 , 88250.39 , 88380.96 , 88008.336,
#        88338.42 , 85187.2  , 85107.336, 85185.375, 85108.664, 85291.72 ,
#        90376.77 , 89789.94 , 89958.164, 89413.45 , 89829.28 , 92879.414,
#        92118.57 , 92271.06 , 91506.305, 92033.56 , 89752.84 , 89229.45 ,
#        89365.11 , 88898.1  , 89281.08 , 86251.85 , 86071.805, 86149.54 ,
#        85986.83 , 86225.59 , 81182.72 , 81348.7  , 81638.98 , 81725.35 ,
#        81419.41 , 82341.42 , 82417.21 , 82676.77 , 82713.17 , 82539.234,
#        80421.06 , 80588.83 , 80957.39 , 81038.61 , 80619.65 , 77686.18 ,
#        78030.72 , 78512.414, 78684.44 , 77953.87 , 75793.85 , 76273.53 ,
#        76804.72 , 77052.96 , 76113.05 , 78515.71 , 78809.86 , 79255.375,
#        79399.96 , 78758.88 , 77816.72 , 78156.26 , 78627.016, 78797.766,
#        78078.336, 78689.35 , 78968.77 , 79409.77 , 79546.99 , 78924.195,
#        79003.516, 79259.125, 79691.734, 79816.766, 79229.28 , 76471.85 ,
#        76899.96 , 77420.76 , 77636.766, 76773.54 , 76531.18 , 76955.1  ,
#        77475.14 , 77687.89 , 76830.92 , 74180.57 , 74755.12 , 75356.26 ,
#        75646.65 , 74544.88 , 75668.55 , 76157.266, 76691.04 , 76943.48 ,
#        75989.14 , 79768.1  , 79997.52 , 80377.766, 80487.77 , 79999.44 ],
#       dtype=float32)

# %%
print(y_test.shape)
# Out:
# (150, 1)

# %%
# rmse = np.sqrt(np.mean(predictions - y_test)**2)
# print("rmse : ", rmse)

# 평균 제곱 오차 계산 : 값의 크기에 따라 예측 결과 평가

# %%
# 다음주 예측 더미 구간 만들기 (220219)

from datetime import datetime
import numpy as np
import pandas as pd

add_pred_date = [datetime(2022,2,21), datetime(2022,2,22), datetime(2022,2,23), datetime(2022,2,24), datetime(2022,2,25)]
add_dummy_data = [np.NaN, np.NaN, np.NaN, np.NaN, np.NaN]
add_predict_date = pd.DataFrame(add_dummy_data, add_pred_date, columns = ['a'])
add_predict_date
# Out:
#              a
# 2022-02-21 NaN
# 2022-02-22 NaN
# 2022-02-23 NaN
# 2022-02-24 NaN
# 2022-02-25 NaN

# %%
valid = pd.concat([data, add_predict_date], axis = 0, ignore_index=False)  # 0 행 방향 연결
valid = valid[training_data_len+5:len(valid)] 
# 예측 구간만 잘라서 정리 150일 분량 (220219)
valid.head()
# Out:
#                High      Low     Open    Close     Volume     Adj Close   a
# 2021-07-16  95100.0  93800.0  94000.0  95000.0   200894.0  94757.039062 NaN
# 2021-07-19  94700.0  93200.0  93800.0  93400.0   324772.0  93161.125000 NaN
# 2021-07-20  93300.0  92100.0  92200.0  92800.0   225549.0  92562.664062 NaN
# 2021-07-21  93400.0  91600.0  93400.0  91900.0   274610.0  91664.960938 NaN
# 2021-07-22  97200.0  93500.0  93500.0  96000.0  1129634.0  95754.476562 NaN

# %%
valid.drop(['a'], axis=1)
valid.tail()
# Out:
#             High  Low  Open  Close  Volume  Adj Close   a
# 2022-02-21   NaN  NaN   NaN    NaN     NaN        NaN NaN
# 2022-02-22   NaN  NaN   NaN    NaN     NaN        NaN NaN
# 2022-02-23   NaN  NaN   NaN    NaN     NaN        NaN NaN
# 2022-02-24   NaN  NaN   NaN    NaN     NaN        NaN NaN
# 2022-02-25   NaN  NaN   NaN    NaN     NaN        NaN NaN

# %%
valid['Predictions'] = predictions
valid.tail()
# Out:
#             High  Low  Open  Close  Volume  Adj Close   a   Predictions
# 2022-02-21   NaN  NaN   NaN    NaN     NaN        NaN NaN  79768.101562
# 2022-02-22   NaN  NaN   NaN    NaN     NaN        NaN NaN  79997.523438
# 2022-02-23   NaN  NaN   NaN    NaN     NaN        NaN NaN  80377.765625
# 2022-02-24   NaN  NaN   NaN    NaN     NaN        NaN NaN  80487.773438
# 2022-02-25   NaN  NaN   NaN    NaN     NaN        NaN NaN  79999.437500

# %%
plt.figure(figsize=(10, 5))
plt.plot(valid['Close'], '-bo')
plt.plot(valid['Predictions'], '-ro')
plt.legend(['Close', 'Predictions'])
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.plot(valid['Close'], '-bo')
plt.plot(valid['Predictions'], '-ro')
plt.legend(['Close', 'Predictions'])

x_min = datetime(2021, 12, 1)
x_max = datetime(2022, 2, 25)
plt.xlim(x_min, x_max)
plt.ylim(65000, 90000)

plt.show()

# %%
# 마지막 5개의 데이터는 다음주 예측값 5개를 나타낸다. (2/21(월)~25(금))
# LSTM을 이용한 주가 예측의 한계 : 예측이 아닌, time shift 결과로 나타난다. (220220)
